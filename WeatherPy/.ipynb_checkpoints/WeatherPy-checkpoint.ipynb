# %%
#Dependencies and Setup
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
from scipy.stats import linregress
import scipy.stats as st

# %%
# Import API key
from config import weather_api_key

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\gagans\desktop\bootcamp\bootcamp\lib\site-packages (0.0.5)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: kdtree>=0.12 in c:\users\gagans\desktop\bootcamp\bootcamp\lib\site-packages (from citipy) (0.16)
# WARNING: You are using pip version 20.1.1; however, version 20.2.4 is available.
# You should consider upgrading via the 'c:\users\gagans\desktop\bootcamp\bootcamp\scripts\python.exe -m pip install --upgrade pip' command.

# %%
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
# Output File (CSV)
Output_data_file = "output_data/cities.csv"

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# # Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 618

# %% [markdown]
# #  Perform API Calls
#
# #### Perform a weather check on each city using a series of successive API calls.
# #### Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print("Beginning Data Retrieval")
print("-------------------------------")

#Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

#Build query url
endpoint = f"{url}appid={weather_api_key}&units={units}&q="

#Creating the response and store in json
#response = requests.get(url).json()

#Set empty list to hold each city's characteristics
city_name_list = []
cloudiness_list = []
country_list = []
data_list = []
humidity_list = []
lat_list = []
lon_list = []
temp_max_list = []
wind_speed_list = []
index_counter = 0
set_counter = 1


#Try to get the city data that is available in the OpenWeather API
for index, city in enumerate (cities, start = 1):
    try:
        response = requests.get(endpoint + city).json()
        city_name_list.append(response["name"])
        cloudiness_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        data_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lat_list.append(response["coord"]["lat"])
        lon_list.append(response["coord"]["lon"])
        temp_max_list.append(response["main"]["temp_max"])
        wind_speed_list.append(response["wind"]["speed"])

        
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
        
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record{index_counter} of set{set_counter}: {city}")
           
        
    except KeyError:
            print("City not found. Skipping...")
            
print("-----------------------------")
print("Data Retrival Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record1 of set1: kahului
# City not found. Skipping...
# Processing Record2 of set1: broken hill
# Processing Record3 of set1: shasta lake
# Processing Record4 of set1: moroto
# Processing Record5 of set1: mar del plata
# Processing Record6 of set1: charagua
# Processing Record7 of set1: petrovsk-zabaykalskiy
# Processing Record8 of set1: kaeo
# Processing Record9 of set1: tuktoyaktuk
# Processing Record10 of set1: qasigiannguit
# Processing Record11 of set1: provideniya
# Processing Record12 of set1: thompson
# Processing Record13 of set1: klaksvik
# Processing Record14 of set1: atuona
# Processing Record15 of set1: punta arenas
# City not found. Skipping...
# Processing Record16 of set1: souillac
# Processing Record17 of set1: kapaa
# Processing Record18 of set1: aykhal
# Processing Record19 of set1: albany
# Processing Record20 of set1: moron
# Processing Record21 of set1: richards bay
# City not found. Skipping...
# Processing Record22 of set1: goregaon
# Processing Record23 of set1: waingapu
# Processing Record24 of set1: busselton
# Processing Record25 of set1: puerto ayora
# Processing Record26 of set1: bredasdorp
# Processing Record27 of set1: maiduguri
# Processing Record28 of set1: ushuaia
# Processing Record29 of set1: seoul
# Processing Record30 of set1: faanui
# Processing Record31 of set1: bluff
# Processing Record32 of set1: mitsamiouli
# Processing Record33 of set1: talnakh
# Processing Record34 of set1: bembereke
# Processing Record35 of set1: milkovo
# Processing Record36 of set1: hermanus
# Processing Record37 of set1: sakaiminato
# Processing Record38 of set1: airai
# Processing Record39 of set1: carnarvon
# Processing Record40 of set1: san pedro pinula
# Processing Record41 of set1: jamestown
# Processing Record42 of set1: cape town
# Processing Record43 of set1: bengkulu
# Processing Record44 of set1: los llanos de aridane
# Processing Record45 of set1: bilma
# Processing Record46 of set1: harper
# Processing Record47 of set1: nouadhibou
# Processing Record48 of set1: laguna
# Processing Record49 of set1: georgetown
# Processing Record50 of set1: hilo
# Processing Record0 of set2: mana
# Processing Record1 of set2: qaanaaq
# Processing Record2 of set2: nikolskoye
# Processing Record3 of set2: rikitea
# Processing Record4 of set2: yellowknife
# Processing Record5 of set2: dikson
# Processing Record6 of set2: beringovskiy
# Processing Record7 of set2: hobart
# Processing Record8 of set2: yar-sale
# Processing Record9 of set2: molteno
# Processing Record10 of set2: severo-kurilsk
# Processing Record11 of set2: avarua
# Processing Record12 of set2: alugan
# Processing Record13 of set2: sars
# Processing Record14 of set2: caxito
# Processing Record15 of set2: sao filipe
# Processing Record16 of set2: haines junction
# Processing Record17 of set2: sitka
# Processing Record18 of set2: yumen
# Processing Record19 of set2: pevek
# Processing Record20 of set2: arraial do cabo
# Processing Record21 of set2: kathmandu
# Processing Record22 of set2: new norfolk
# City not found. Skipping...
# Processing Record23 of set2: yeppoon
# Processing Record24 of set2: cabadiangan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record25 of set2: bethel
# City not found. Skipping...
# Processing Record26 of set2: jimenez
# Processing Record27 of set2: hambantota
# Processing Record28 of set2: cabo san lucas
# Processing Record29 of set2: kushmurun
# Processing Record30 of set2: bonavista
# Processing Record31 of set2: mayo
# Processing Record32 of set2: esik
# Processing Record33 of set2: port alfred
# Processing Record34 of set2: pangnirtung
# City not found. Skipping...
# Processing Record35 of set2: touros
# Processing Record36 of set2: barrow
# Processing Record37 of set2: igrim
# Processing Record38 of set2: xai-xai
# Processing Record39 of set2: vaini
# Processing Record40 of set2: zhigansk
# Processing Record41 of set2: kokopo
# Processing Record42 of set2: northam
# Processing Record43 of set2: saint-philippe
# Processing Record44 of set2: naifaru
# Processing Record45 of set2: eureka
# Processing Record46 of set2: norman wells
# Processing Record47 of set2: beloha
# City not found. Skipping...
# Processing Record48 of set2: cockburn town
# Processing Record49 of set2: veinticinco de diciembre
# Processing Record50 of set2: mataura
# Processing Record0 of set3: saint-pierre
# Processing Record1 of set3: salalah
# City not found. Skipping...
# Processing Record2 of set3: saskylakh
# Processing Record3 of set3: kupang
# City not found. Skipping...
# Processing Record4 of set3: kokkola
# Processing Record5 of set3: port elizabeth
# City not found. Skipping...
# City not found. Skipping...
# Processing Record6 of set3: krasnoborsk
# Processing Record7 of set3: castro
# Processing Record8 of set3: luanda
# Processing Record9 of set3: hasaki
# City not found. Skipping...
# Processing Record10 of set3: yulara
# Processing Record11 of set3: aloleng
# Processing Record12 of set3: bull savanna
# Processing Record13 of set3: sur
# Processing Record14 of set3: kodiak
# Processing Record15 of set3: korla
# Processing Record16 of set3: mahebourg
# Processing Record17 of set3: chapais
# Processing Record18 of set3: arkansas city
# Processing Record19 of set3: eyl
# Processing Record20 of set3: francistown
# Processing Record21 of set3: nanortalik
# City not found. Skipping...
# City not found. Skipping...
# Processing Record22 of set3: khatanga
# Processing Record23 of set3: batagay
# Processing Record24 of set3: el alto
# Processing Record25 of set3: cidreira
# Processing Record26 of set3: nanzhou
# City not found. Skipping...
# Processing Record27 of set3: banmankhi
# Processing Record28 of set3: key largo
# Processing Record29 of set3: amarante do maranhao
# Processing Record30 of set3: katangli
# Processing Record31 of set3: santa maria
# Processing Record32 of set3: hwange
# City not found. Skipping...
# City not found. Skipping...
# Processing Record33 of set3: bandarbeyla
# City not found. Skipping...
# Processing Record34 of set3: bambous virieux
# Processing Record35 of set3: torbay
# Processing Record36 of set3: luderitz
# Processing Record37 of set3: rochegda
# Processing Record38 of set3: upernavik
# Processing Record39 of set3: lagoa
# Processing Record40 of set3: tombouctou
# Processing Record41 of set3: evensk
# Processing Record42 of set3: ancud
# Processing Record43 of set3: vardo
# Processing Record44 of set3: sungaipenuh
# Processing Record45 of set3: port-gentil
# Processing Record46 of set3: teguldet
# Processing Record47 of set3: cayenne
# Processing Record48 of set3: east london
# Processing Record49 of set3: vestmannaeyjar
# Processing Record50 of set3: mosina
# Processing Record0 of set4: hithadhoo
# Processing Record1 of set4: ankazobe
# Processing Record2 of set4: fortuna
# Processing Record3 of set4: ketchikan
# Processing Record4 of set4: hammerfest
# Processing Record5 of set4: yuli
# Processing Record6 of set4: beihai
# Processing Record7 of set4: lompoc
# Processing Record8 of set4: auxerre
# Processing Record9 of set4: luwuk
# Processing Record10 of set4: ostrovnoy
# Processing Record11 of set4: grand gaube
# Processing Record12 of set4: zhezkazgan
# Processing Record13 of set4: giresun
# Processing Record14 of set4: esperance
# Processing Record15 of set4: dingle
# Processing Record16 of set4: nortelandia
# Processing Record17 of set4: kaitangata
# Processing Record18 of set4: saldanha
# City not found. Skipping...
# Processing Record19 of set4: maningrida
# Processing Record20 of set4: narsaq
# Processing Record21 of set4: alofi
# Processing Record22 of set4: karratha
# Processing Record23 of set4: lebu
# Processing Record24 of set4: ukhta
# Processing Record25 of set4: longyearbyen
# Processing Record26 of set4: lapua
# City not found. Skipping...
# Processing Record27 of set4: komsomolskiy
# Processing Record28 of set4: margate
# Processing Record29 of set4: xuddur
# Processing Record30 of set4: benguela
# Processing Record31 of set4: paka
# Processing Record32 of set4: provost
# City not found. Skipping...
# Processing Record33 of set4: peniche
# Processing Record34 of set4: bubaque
# Processing Record35 of set4: hamilton
# Processing Record36 of set4: hami
# Processing Record37 of set4: bat yam
# Processing Record38 of set4: butaritari
# Processing Record39 of set4: busko-zdroj
# Processing Record40 of set4: manga
# Processing Record41 of set4: kavaratti
# Processing Record42 of set4: vila franca do campo
# Processing Record43 of set4: ca mau
# Processing Record44 of set4: salinas
# Processing Record45 of set4: taber
# Processing Record46 of set4: ahipara
# Processing Record47 of set4: kuah
# Processing Record48 of set4: fuling
# Processing Record49 of set4: oktyabrskoye
# Processing Record50 of set4: sampit
# Processing Record0 of set5: tasiilaq
# Processing Record1 of set5: lavrentiya
# Processing Record2 of set5: porto belo
# Processing Record3 of set5: kiunga
# Processing Record4 of set5: camacha
# Processing Record5 of set5: oussouye
# Processing Record6 of set5: guerrero negro
# Processing Record7 of set5: aboisso
# Processing Record8 of set5: sao joao da barra
# Processing Record9 of set5: lensk
# Processing Record10 of set5: okha
# Processing Record11 of set5: kletnya
# Processing Record12 of set5: coffs harbour
# City not found. Skipping...
# City not found. Skipping...
# Processing Record13 of set5: corinto
# Processing Record14 of set5: saint george
# Processing Record15 of set5: aizkraukle
# Processing Record16 of set5: rantepao
# Processing Record17 of set5: ribeira grande
# City not found. Skipping...
# Processing Record18 of set5: geraldton
# Processing Record19 of set5: pyapon
# Processing Record20 of set5: kavieng
# Processing Record21 of set5: carutapera
# Processing Record22 of set5: tuatapere
# Processing Record23 of set5: lokosovo
# Processing Record24 of set5: karatuzskoye
# Processing Record25 of set5: chicama
# Processing Record26 of set5: encruzilhada do sul
# Processing Record27 of set5: manono
# Processing Record28 of set5: taltal
# Processing Record29 of set5: mariental
# Processing Record30 of set5: namatanai
# Processing Record31 of set5: namtsy
# Processing Record32 of set5: codrington
# Processing Record33 of set5: fayetteville
# City not found. Skipping...
# Processing Record34 of set5: pisco
# Processing Record35 of set5: chokurdakh
# City not found. Skipping...
# Processing Record36 of set5: ganzhou
# Processing Record37 of set5: port hedland
# Processing Record38 of set5: sioux lookout
# Processing Record39 of set5: nantucket
# Processing Record40 of set5: gummidipundi
# Processing Record41 of set5: marovoay
# Processing Record42 of set5: brigantine
# Processing Record43 of set5: upington
# Processing Record44 of set5: sikonge
# Processing Record45 of set5: nhulunbuy
# Processing Record46 of set5: muskegon
# Processing Record47 of set5: mnogovershinnyy
# Processing Record48 of set5: shitanjing
# Processing Record49 of set5: saint-ambroise
# Processing Record50 of set5: upata
# Processing Record0 of set6: bremervorde
# Processing Record1 of set6: south yarmouth
# Processing Record2 of set6: kibala
# Processing Record3 of set6: obo
# Processing Record4 of set6: north branch
# Processing Record5 of set6: te anau
# Processing Record6 of set6: lubango
# Processing Record7 of set6: north bend
# Processing Record8 of set6: kloulklubed
# Processing Record9 of set6: eenhana
# Processing Record10 of set6: miri
# Processing Record11 of set6: denver
# Processing Record12 of set6: anori
# Processing Record13 of set6: kleive
# Processing Record14 of set6: matadi
# Processing Record15 of set6: cherskiy
# Processing Record16 of set6: san quintin
# City not found. Skipping...
# Processing Record17 of set6: krasne
# Processing Record18 of set6: elk river
# Processing Record19 of set6: mumbwa
# Processing Record20 of set6: yangambi
# Processing Record21 of set6: palmer
# Processing Record22 of set6: viedma
# Processing Record23 of set6: ajaccio
# Processing Record24 of set6: kulhudhuffushi
# City not found. Skipping...
# Processing Record25 of set6: isangel
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record26 of set6: adrar
# Processing Record27 of set6: abu dhabi
# Processing Record28 of set6: chuy
# Processing Record29 of set6: baikunthpur
# Processing Record30 of set6: tiksi
# Processing Record31 of set6: blythe
# Processing Record32 of set6: sistranda
# Processing Record33 of set6: namibe
# Processing Record34 of set6: tutoia
# Processing Record35 of set6: xifeng
# Processing Record36 of set6: shelburne
# Processing Record37 of set6: coihaique
# Processing Record38 of set6: anamur
# Processing Record39 of set6: sagua la grande
# Processing Record40 of set6: vao
# Processing Record41 of set6: balikpapan
# Processing Record42 of set6: lingsugur
# Processing Record43 of set6: matara
# Processing Record44 of set6: pastos bons
# Processing Record45 of set6: mitu
# Processing Record46 of set6: kapoeta
# City not found. Skipping...
# Processing Record47 of set6: bay roberts
# Processing Record48 of set6: lorengau
# Processing Record49 of set6: kieta
# Processing Record50 of set6: lodja
# Processing Record0 of set7: kalang
# Processing Record1 of set7: cerro largo
# Processing Record2 of set7: pedernales
# City not found. Skipping...
# Processing Record3 of set7: odienne
# Processing Record4 of set7: srednekolymsk
# City not found. Skipping...
# Processing Record5 of set7: urucara
# Processing Record6 of set7: trincomalee
# Processing Record7 of set7: jurm
# Processing Record8 of set7: gobabis
# Processing Record9 of set7: pingliang
# Processing Record10 of set7: stornoway
# City not found. Skipping...
# Processing Record11 of set7: beatrice
# Processing Record12 of set7: salina cruz
# Processing Record13 of set7: khandbari
# Processing Record14 of set7: russell
# Processing Record15 of set7: valparaiso
# Processing Record16 of set7: koslan
# Processing Record17 of set7: banjar
# Processing Record18 of set7: orlik
# Processing Record19 of set7: oyama
# Processing Record20 of set7: biloela
# Processing Record21 of set7: saint-georges
# Processing Record22 of set7: rundu
# Processing Record23 of set7: gotsu
# Processing Record24 of set7: hailey
# Processing Record25 of set7: iqaluit
# Processing Record26 of set7: thanh hoa
# Processing Record27 of set7: victoria
# Processing Record28 of set7: toamasina
# Processing Record29 of set7: ilulissat
# Processing Record30 of set7: lelydorp
# Processing Record31 of set7: padang
# Processing Record32 of set7: marsh harbour
# Processing Record33 of set7: erzin
# Processing Record34 of set7: zihuatanejo
# Processing Record35 of set7: zheleznodorozhnyy
# Processing Record36 of set7: baruun-urt
# Processing Record37 of set7: lata
# Processing Record38 of set7: kirakira
# Processing Record39 of set7: san luis
# Processing Record40 of set7: jiuquan
# Processing Record41 of set7: mantua
# Processing Record42 of set7: hakkari
# Processing Record43 of set7: dickinson
# Processing Record44 of set7: kilindoni
# City not found. Skipping...
# Processing Record45 of set7: tekari
# Processing Record46 of set7: isiro
# Processing Record47 of set7: lucani
# Processing Record48 of set7: grindavik
# Processing Record49 of set7: clyde river
# Processing Record50 of set7: hokitika
# Processing Record0 of set8: petropavlovsk-kamchatskiy
# Processing Record1 of set8: gamba
# Processing Record2 of set8: vetapalem
# Processing Record3 of set8: danville
# Processing Record4 of set8: nanlong
# Processing Record5 of set8: aksarka
# Processing Record6 of set8: san cristobal
# Processing Record7 of set8: sept-iles
# Processing Record8 of set8: khakhea
# Processing Record9 of set8: port hardy
# Processing Record10 of set8: uppsala
# Processing Record11 of set8: fukue
# Processing Record12 of set8: berlevag
# Processing Record13 of set8: walvis bay
# Processing Record14 of set8: beauvais
# Processing Record15 of set8: bien hoa
# City not found. Skipping...
# Processing Record16 of set8: hobyo
# Processing Record17 of set8: byron bay
# Processing Record18 of set8: martapura
# Processing Record19 of set8: belem de sao francisco
# Processing Record20 of set8: arona
# City not found. Skipping...
# Processing Record21 of set8: vila velha
# Processing Record22 of set8: ponta do sol
# Processing Record23 of set8: paita
# City not found. Skipping...
# Processing Record24 of set8: the valley
# Processing Record25 of set8: egvekinot
# Processing Record26 of set8: imeni babushkina
# Processing Record27 of set8: iracoubo
# Processing Record28 of set8: shache
# Processing Record29 of set8: aswan
# Processing Record30 of set8: simoes
# Processing Record31 of set8: orcopampa
# Processing Record32 of set8: iralaya
# Processing Record33 of set8: ukiah
# Processing Record34 of set8: coahuayana
# Processing Record35 of set8: morros
# Processing Record36 of set8: quelimane
# Processing Record37 of set8: port blair
# Processing Record38 of set8: kruisfontein
# Processing Record39 of set8: naze
# Processing Record40 of set8: hillsborough
# City not found. Skipping...
# Processing Record41 of set8: priladozhskiy
# Processing Record42 of set8: sohag
# Processing Record43 of set8: boguchany
# Processing Record44 of set8: ahome
# Processing Record45 of set8: constitucion
# Processing Record46 of set8: nome
# Processing Record47 of set8: ucluelet
# Processing Record48 of set8: dubbo
# Processing Record49 of set8: karaton
# Processing Record50 of set8: saravan
# Processing Record0 of set9: caiaponia
# Processing Record1 of set9: svetlogorsk
# Processing Record2 of set9: san andres
# Processing Record3 of set9: khatassy
# Processing Record4 of set9: ixtapa
# Processing Record5 of set9: ostersund
# Processing Record6 of set9: vanimo
# Processing Record7 of set9: jumla
# Processing Record8 of set9: necochea
# Processing Record9 of set9: skibbereen
# Processing Record10 of set9: longavi
# Processing Record11 of set9: yerbogachen
# Processing Record12 of set9: debre sina
# Processing Record13 of set9: san benito
# Processing Record14 of set9: tunceli
# Processing Record15 of set9: nago
# Processing Record16 of set9: whitehorse
# Processing Record17 of set9: griffith
# Processing Record18 of set9: barcelos
# Processing Record19 of set9: kalininsk
# Processing Record20 of set9: huangcun
# Processing Record21 of set9: srono
# Processing Record22 of set9: tlalchapa
# Processing Record23 of set9: bealanana
# Processing Record24 of set9: leningradskiy
# Processing Record25 of set9: dunedin
# Processing Record26 of set9: skjervoy
# Processing Record27 of set9: grand forks
# Processing Record28 of set9: jizan
# Processing Record29 of set9: arcos
# Processing Record30 of set9: zabaykalsk
# Processing Record31 of set9: sault sainte marie
# Processing Record32 of set9: sarlat-la-caneda
# Processing Record33 of set9: kyrylivka
# Processing Record34 of set9: montevideo
# Processing Record35 of set9: finschhafen
# Processing Record36 of set9: saint-francois
# Processing Record37 of set9: manavalakurichi
# Processing Record38 of set9: port hawkesbury
# Processing Record39 of set9: bara
# Processing Record40 of set9: lytkarino
# Processing Record41 of set9: panjab
# Processing Record42 of set9: matagami
# Processing Record43 of set9: shimoda
# Processing Record44 of set9: meulaboh
# Processing Record45 of set9: nabire
# Processing Record46 of set9: lumeje
# Processing Record47 of set9: mahajanga
# Processing Record48 of set9: moshenskoye
# Processing Record49 of set9: college
# Processing Record50 of set9: wanning
# Processing Record0 of set10: mackay
# Processing Record1 of set10: inhambane
# Processing Record2 of set10: pangody
# Processing Record3 of set10: allende
# Processing Record4 of set10: tura
# Processing Record5 of set10: somerville
# Processing Record6 of set10: coquimbo
# Processing Record7 of set10: havre-saint-pierre
# Processing Record8 of set10: mogadishu
# Processing Record9 of set10: belaya gora
# Processing Record10 of set10: languyan
# Processing Record11 of set10: dillingen
# Processing Record12 of set10: raudeberg
# Processing Record13 of set10: muromtsevo
# Processing Record14 of set10: sabha
# Processing Record15 of set10: sarkand
# Processing Record16 of set10: aksu
# Processing Record17 of set10: cap malheureux
# Processing Record18 of set10: itarema
# Processing Record19 of set10: acapulco
# Processing Record20 of set10: sainte-maxime
# Processing Record21 of set10: buchanan
# City not found. Skipping...
# Processing Record22 of set10: lagos
# Processing Record23 of set10: rabo de peixe
# Processing Record24 of set10: santa cruz del sur
# Processing Record25 of set10: dubuque
# Processing Record26 of set10: salinopolis
# Processing Record27 of set10: misratah
# Processing Record28 of set10: sorland
# Processing Record29 of set10: bathsheba
# Processing Record30 of set10: bayeux
# Processing Record31 of set10: lahaina
# Processing Record32 of set10: pandan
# Processing Record33 of set10: svay rieng
# Processing Record34 of set10: kudahuvadhoo
# Processing Record35 of set10: muzhi
# Processing Record36 of set10: kondinskoye
# Processing Record37 of set10: sterling
# Processing Record38 of set10: pemba
# Processing Record39 of set10: orshanka
# Processing Record40 of set10: kashin
# Processing Record41 of set10: kungurtug
# Processing Record42 of set10: caravelas
# Processing Record43 of set10: am timan
# Processing Record44 of set10: westport
# City not found. Skipping...
# Processing Record45 of set10: disna
# Processing Record46 of set10: sinjar
# Processing Record47 of set10: mareeba
# Processing Record48 of set10: methven
# Processing Record49 of set10: husavik
# City not found. Skipping...
# Processing Record50 of set10: buala
# Processing Record0 of set11: atar
# Processing Record1 of set11: fort nelson
# Processing Record2 of set11: atyrau
# Processing Record3 of set11: kralendijk
# Processing Record4 of set11: manokwari
# Processing Record5 of set11: katsuura
# Processing Record6 of set11: miramar
# Processing Record7 of set11: honiara
# Processing Record8 of set11: calvinia
# Processing Record9 of set11: olafsvik
# Processing Record10 of set11: nishihara
# City not found. Skipping...
# Processing Record11 of set11: evanston
# Processing Record12 of set11: otradnoye
# Processing Record13 of set11: krivosheino
# City not found. Skipping...
# Processing Record14 of set11: porto novo
# Processing Record15 of set11: bereda
# Processing Record16 of set11: severo-yeniseyskiy
# Processing Record17 of set11: grootfontein
# Processing Record18 of set11: nyimba
# Processing Record19 of set11: talant
# Processing Record20 of set11: pochinki
# Processing Record21 of set11: moindou
# Processing Record22 of set11: avera
# Processing Record23 of set11: emmen
# Processing Record24 of set11: yanaul
# Processing Record25 of set11: sanchez
# Processing Record26 of set11: puerto colombia
# Processing Record27 of set11: gizo
# Processing Record28 of set11: tawang
# Processing Record29 of set11: praia da vitoria
# Processing Record30 of set11: murygino
# Processing Record31 of set11: ovsyanka
# Processing Record32 of set11: prince rupert
# Processing Record33 of set11: biak
# Processing Record34 of set11: fallon
# Processing Record35 of set11: marsa matruh
# Processing Record36 of set11: marawi
# Processing Record37 of set11: ghanzi
# Processing Record38 of set11: lethem
# Processing Record39 of set11: mujiayingzi
# Processing Record40 of set11: berezovyy
# Processing Record41 of set11: fort frances
# Processing Record42 of set11: diego de almagro
# Processing Record43 of set11: vuktyl
# Processing Record44 of set11: manicore
# Processing Record45 of set11: buenos aires
# Processing Record46 of set11: phultala
# Processing Record47 of set11: mao
# Processing Record48 of set11: lazaro cardenas
# Processing Record49 of set11: ullal
# Processing Record50 of set11: asau
# Processing Record0 of set12: constantine
# Processing Record1 of set12: olinda
# Processing Record2 of set12: turan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record3 of set12: awjilah
# Processing Record4 of set12: simao
# Processing Record5 of set12: sokoni
# Processing Record6 of set12: panguna
# Processing Record7 of set12: cabedelo
# Processing Record8 of set12: save
# -----------------------------
# Data Retrival Complete
# -----------------------------

# %% [markdown]
# # Convert Raw Data to DataFrame
#
# #### Export the city data into a .csv.
# #### Display the DataFrame

# %%
#Creating a dataframe with information received
Weather_pd = pd.DataFrame({
                        "City" : city_name_list, 
                        "Cloudiness" : cloudiness_list,
                        "Country" : country_list,
                        "Date" : data_list,
                        "Humidity" : humidity_list,
                        "Lat" : lat_list,
                        "Lon" : lon_list,
                        "Max Temp" : temp_max_list,
                        "Wind Speed" : wind_speed_list 
    
})

# %%
#Counting the data
Weather_pd.count()
# Out:
# City          569
# Cloudiness    569
# Country       569
# Date          569
# Humidity      569
# Lat           569
# Lon           569
# Max Temp      569
# Wind Speed    569
# dtype: int64

# %%
#Displaying the DataFrame
Weather_pd.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lon  \
# 0        Kahului          75      US  1604013222        66  20.89 -156.47
# 1    Broken Hill          75      AU  1604013299        76 -31.95  141.43
# 2    Lake Shasta           0      US  1604013300        16  40.68 -122.37
# 3         Moroto         100      UG  1604013300        76   2.53   34.67
# 4  Mar del Plata          20      AR  1604013006        62 -38.00  -57.56
#
#    Max Temp  Wind Speed
# 0     84.20        9.17
# 1     55.40       20.80
# 2     80.01        5.55
# 3     66.78        1.68
# 4     51.80        9.17

# %%
#Export city data into a .CSV file
Weather_pd.to_csv("Output_data_file", index = False)

# %% [markdown]
# # Plotting the Data
#
# #### Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# #### Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Creating the Latitude vs. Temperature Scatter Plot

#Setting the plot title, xlabel, ylabel and grid
plt.title("City Latitude vs.Max Temperature(10/27/2020)", fontsize = 20)
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Max Temperature (F)", fontsize = 12)

plt.scatter(Weather_pd["Lat"],Weather_pd["Max Temp"], facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)

#Saving the plot fig as .png
plt.savefig("../Images/City Latitude vs Max Temperature.png")
plt.show()

# %% [markdown]
# ###### As the Latitude is increasing the temperature drops

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Creating the Latitude vs. Humidity Scatter Plot

#Setting the plot title, xlabel, ylabel and grid
plt.title("City Latitude vs. Humidity(10/27/2020)", fontsize = 20)
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Humidity (%)", fontsize = 12)

plt.scatter(Weather_pd["Lat"],Weather_pd["Humidity"], facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)

#Saving the plot fig as .png
plt.savefig("../Images/City Latitude vs Humidity.png")

plt.show()

# %% [markdown]
# ###### As Latitude increases Humidity also increases

# %% [markdown]
# ##  Latitude vs. Cloudiness Plot

# %%
#Creating the Latitude vs. Cloudiness Scatter Plot

#Setting the plot title, xlabel, ylabel and grid
plt.title("City Latitude vs. Cloudiness(10/27/2020)", fontsize = 20)
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Cloudiness (%)", fontsize = 12)

plt.scatter(Weather_pd["Lat"],Weather_pd["Cloudiness"], facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)


#Saving the plot fig as .png
plt.savefig("../Images/City Latitude vs Cloudiness.png")

plt.show()

# %% [markdown]
# ###### City cloudiness is spread all over the latitude

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Creating the Latitude vs. Wind Speed Scatter Plot

#Setting the plot title, xlabel, ylabel and grid
plt.title("City Latitude vs. Wind Speed(10/27/2020)", fontsize = 20)
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Wind Speed (mph)", fontsize = 12)

plt.scatter(Weather_pd["Lat"],Weather_pd["Wind Speed"], facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)

#Saving the plot fig as .png
plt.savefig("../Images/City Latitude vs Wind Speed.png")

plt.show()

# %% [markdown]
# ###### As the laitude increases, Wind speed is spreading at same mph

# %% [markdown]
# #  Linear Regression

# %%
#Creating DataFrame for Northern Henisphere and Southern Hemisphere
southern_hemisphere = Weather_pd.loc[Weather_pd["Lat"]<0]
northern_hemisphere = Weather_pd.loc[Weather_pd["Lat"]>=0]

# %% [markdown]
# ##  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Creating linear regression and scatter plots
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Max Temp vs Latitude Linear Regression(Northern Hemisphere)", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (10,20), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Max Temp", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)


#Saving the plot fig as .png
plt.savefig("../Images/Temperatues at Latitude Positions(Northern Hemisphere.png")

print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.731363841056476

# %% [markdown]
# ###### The plot shows negative correlation between Max Temp and Latitude in Northern Hemisphere

# %% [markdown]
# ##  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Max Temp vs Latitude Linear Regression(Southern Hemisphere)", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (-20,5), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Max Temp", fontsize = 12)
plt.xlim = (0, -60)
plt.ylim = (40, 100)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)

#Saving the plot fig as .png
plt.savefig("../Images/Temperatues at Latitude Positions(Southern Hemisphere.png")

print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.5201039133486368

# %% [markdown]
# ###### The plot shows positive correlation between Max Temp and Latitude in Southern Hemisphere

# %% [markdown]
# ## Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (50,20), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Humidity (%)", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)


#Saving the plot fig as .png
plt.savefig("../Images/Northern Hemisphere - Humidity (%) vs. Latitude.png")

print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.056194855201906146

# %% [markdown]
# ##### The plot shows moderate positive correlation between Humidity(%) and Latitude in Northern Hemisphere

# %% [markdown]
# ##  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (-20,20), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Humidity (%)", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)


#Saving the plot fig as .png
plt.savefig("../Images/Southern Hemisphere - Humidity (%) vs. Latitude.png")

print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.04578758653623823

# %% [markdown]
# ##### The plot shows moderate positive correlation between Humidity(%) and Latitude in Southern Hemisphere

# %% [markdown]
# ## Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (10,20), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Cloudiness (%)", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)


#Saving the plot fig as .png
plt.savefig("../Images/Northern Hemisphere - Cloudiness (%) vs. Latitude.png")

print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.018294476223831426

# %% [markdown]
# ##### The plot shows moderate positive correlation between Cloudiness(%) and Latitude in Northern Hemisphere

# %% [markdown]
# ## Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (-50,80), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Cloudiness (%)", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)

#Saving the plot fig as .png
plt.savefig("../Images/Southern Hemisphere - Cloudiness (%) vs. Latitude.png")

print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.040874003878227504

# %% [markdown]
# ##### The plot shows positive correlation between Cloudiness(%) and Latitude in Southern Hemisphere

# %% [markdown]
# ## Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Northern Hemisphere - Wind Speed(mph) vs. Latitude", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (60,10), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Wind Speed", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)

#Saving the plot fig as .png
plt.savefig("../Images/Northern Hemisphere - Wind Speed(mph) vs. Latitude.png")

print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.006101188301716852

# %% [markdown]
# ##### The plot shows moderate positive correlation between Wind Speed(mph) and Latitude in Northern Hemisphere

# %% [markdown]
# ## Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Southern Hemisphere - Wind Speed(mph) vs. Latitude", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (-50,8), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Wind Speed(mph)", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)

#Saving the plot fig as .png
plt.savefig("../Images/Southern Hemisphere - Wind Speed(mph) vs. Latitude.png")

print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.032821876256360225

# %% [markdown]
# ##### The plot shows negative correlation between Wind Speed(mph) and Latitude in Southern Hemisphere

# %% [markdown]
# ### Observations

# %% [markdown]
# ##### 1.Maximum temperature and Latitude work differently in Northern Hemishpere amd Southern Hemisphere. In Northern Hemishpere, max temperature and latitude are negatively correlated, which means that if the latitude increase max temperature decreases. Whereas in southern hemisphere its vice versa
#
# ##### 2.Cloudiness (%) and Latitude work similarly in both Northern Hemishpere amd Southern Hemisphere. The relation between cloudiness and latitude is moderately positively correlated in both hemispheres, which means as the latitude increases, the cloudiness also increases.
#
# ##### 3.For all the cities analyzed in the scatter plot, the cloudiness seem to be spead around all the latitudes.
