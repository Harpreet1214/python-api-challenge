# %%
#Dependencies and Setup
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
from scipy.stats import linregress
import scipy.stats as st

# %%
# Import API key
from config import weather_api_key

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\gagans\desktop\bootcamp\bootcamp\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\gagans\desktop\bootcamp\bootcamp\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.1.1; however, version 20.2.4 is available.
# You should consider upgrading via the 'c:\users\gagans\desktop\bootcamp\bootcamp\scripts\python.exe -m pip install --upgrade pip' command.

# %%
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
# Output File (CSV)
Output_data_file = "output_data/cities.csv"

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# # Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 627

# %% [markdown]
# #  Perform API Calls
#
# #### Perform a weather check on each city using a series of successive API calls.
# #### Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print("Beginning Data Retrieval")
print("-------------------------------")

#Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

#Build query url
endpoint = f"{url}appid={weather_api_key}&units={units}&q="

#Creating the response and store in json
#response = requests.get(url).json()

#Set empty list to hold each city's characteristics
city_name_list = []
cloudiness_list = []
country_list = []
data_list = []
humidity_list = []
lat_list = []
lon_list = []
temp_max_list = []
wind_speed_list = []
index_counter = 0
set_counter = 1


#Try to get the city data that is available in the OpenWeather API
for index, city in enumerate (cities, start = 1):
    try:
        response = requests.get(endpoint + city).json()
        city_name_list.append(response["name"])
        cloudiness_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        data_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lat_list.append(response["coord"]["lat"])
        lon_list.append(response["coord"]["lon"])
        temp_max_list.append(response["main"]["temp_max"])
        wind_speed_list.append(response["wind"]["speed"])

        
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
        
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record{index_counter} of set{set_counter}: {city}")
           
        
    except KeyError:
            print("City not found. Skipping...")
            
print("-----------------------------")
print("Data Retrival Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record1 of set1: dikson
# Processing Record2 of set1: lagoa
# Processing Record3 of set1: lahat
# Processing Record4 of set1: mataura
# Processing Record5 of set1: yellowknife
# Processing Record6 of set1: rikitea
# Processing Record7 of set1: punta arenas
# Processing Record8 of set1: busselton
# Processing Record9 of set1: castro
# Processing Record10 of set1: saskylakh
# City not found. Skipping...
# Processing Record11 of set1: deputatskiy
# Processing Record12 of set1: vaini
# Processing Record13 of set1: east london
# Processing Record14 of set1: jiazi
# Processing Record15 of set1: kayerkan
# Processing Record16 of set1: isangel
# Processing Record17 of set1: bluff
# City not found. Skipping...
# Processing Record18 of set1: butaritari
# Processing Record19 of set1: ushuaia
# Processing Record20 of set1: cidreira
# Processing Record21 of set1: zhigansk
# Processing Record22 of set1: paraje nuevo
# Processing Record23 of set1: cape town
# Processing Record24 of set1: hobart
# Processing Record25 of set1: merano
# Processing Record26 of set1: amapa
# Processing Record27 of set1: abnub
# Processing Record28 of set1: kahului
# Processing Record29 of set1: cherskiy
# Processing Record30 of set1: asyut
# Processing Record31 of set1: ubinskoye
# Processing Record32 of set1: touros
# Processing Record33 of set1: kapaa
# Processing Record34 of set1: hilo
# Processing Record35 of set1: port-gentil
# Processing Record36 of set1: dubreka
# Processing Record37 of set1: mapiripan
# Processing Record38 of set1: saint-augustin
# Processing Record39 of set1: chicama
# Processing Record40 of set1: katsuura
# Processing Record41 of set1: synya
# Processing Record42 of set1: skibbereen
# Processing Record43 of set1: sola
# Processing Record44 of set1: sao jose da coroa grande
# Processing Record45 of set1: kletnya
# Processing Record46 of set1: mahebourg
# Processing Record47 of set1: oistins
# Processing Record48 of set1: noumea
# Processing Record49 of set1: at-bashi
# Processing Record50 of set1: tumaco
# Processing Record0 of set2: port alfred
# Processing Record1 of set2: lorengau
# Processing Record2 of set2: nunoa
# Processing Record3 of set2: ancud
# Processing Record4 of set2: hays
# Processing Record5 of set2: lulea
# Processing Record6 of set2: takanabe
# Processing Record7 of set2: winnemucca
# City not found. Skipping...
# City not found. Skipping...
# Processing Record8 of set2: touho
# Processing Record9 of set2: havoysund
# Processing Record10 of set2: ko samui
# Processing Record11 of set2: buala
# Processing Record12 of set2: hithadhoo
# Processing Record13 of set2: impfondo
# Processing Record14 of set2: morros
# City not found. Skipping...
# Processing Record15 of set2: mozhga
# Processing Record16 of set2: bang saphan
# City not found. Skipping...
# Processing Record17 of set2: khatanga
# Processing Record18 of set2: ilulissat
# Processing Record19 of set2: shiyan
# Processing Record20 of set2: bonavista
# Processing Record21 of set2: kuppam
# Processing Record22 of set2: tiksi
# Processing Record23 of set2: nichinan
# Processing Record24 of set2: albany
# Processing Record25 of set2: rio grande
# Processing Record26 of set2: jamestown
# Processing Record27 of set2: mar del plata
# Processing Record28 of set2: santiago del estero
# City not found. Skipping...
# Processing Record29 of set2: codrington
# Processing Record30 of set2: alice springs
# Processing Record31 of set2: thompson
# Processing Record32 of set2: saint george
# Processing Record33 of set2: gillette
# Processing Record34 of set2: acurenam
# Processing Record35 of set2: bethel
# Processing Record36 of set2: puerto ayora
# Processing Record37 of set2: avarua
# City not found. Skipping...
# Processing Record38 of set2: hasaki
# Processing Record39 of set2: coihaique
# Processing Record40 of set2: new norfolk
# Processing Record41 of set2: cayey
# Processing Record42 of set2: inuvik
# Processing Record43 of set2: airai
# Processing Record44 of set2: ayan
# Processing Record45 of set2: kununurra
# Processing Record46 of set2: tema
# Processing Record47 of set2: vredendal
# Processing Record48 of set2: yerbogachen
# Processing Record49 of set2: upernavik
# Processing Record50 of set2: kristianstad
# Processing Record0 of set3: clinton
# Processing Record1 of set3: ende
# Processing Record2 of set3: norman wells
# Processing Record3 of set3: port lincoln
# Processing Record4 of set3: port elizabeth
# Processing Record5 of set3: barrow
# City not found. Skipping...
# Processing Record6 of set3: menongue
# Processing Record7 of set3: bambous virieux
# Processing Record8 of set3: vao
# Processing Record9 of set3: ostrovnoy
# City not found. Skipping...
# Processing Record10 of set3: leningradskiy
# Processing Record11 of set3: bredasdorp
# Processing Record12 of set3: naze
# Processing Record13 of set3: simao
# Processing Record14 of set3: udachnyy
# Processing Record15 of set3: tura
# Processing Record16 of set3: shelby
# Processing Record17 of set3: avera
# Processing Record18 of set3: chincha alta
# Processing Record19 of set3: olafsvik
# Processing Record20 of set3: chimbote
# Processing Record21 of set3: diffa
# Processing Record22 of set3: nerchinskiy zavod
# Processing Record23 of set3: pevek
# Processing Record24 of set3: chuy
# Processing Record25 of set3: boende
# Processing Record26 of set3: yumen
# Processing Record27 of set3: lasa
# Processing Record28 of set3: broken hill
# Processing Record29 of set3: hermanus
# Processing Record30 of set3: carnarvon
# Processing Record31 of set3: puri
# Processing Record32 of set3: tromso
# Processing Record33 of set3: atuona
# Processing Record34 of set3: tasiilaq
# City not found. Skipping...
# City not found. Skipping...
# Processing Record35 of set3: ribeira grande
# Processing Record36 of set3: ngunguru
# Processing Record37 of set3: jaicos
# Processing Record38 of set3: warren
# Processing Record39 of set3: ponta do sol
# Processing Record40 of set3: neuquen
# Processing Record41 of set3: pangnirtung
# Processing Record42 of set3: la huacana
# Processing Record43 of set3: wittlich
# Processing Record44 of set3: qaanaaq
# Processing Record45 of set3: cabo san lucas
# Processing Record46 of set3: kamyzyak
# Processing Record47 of set3: alugan
# Processing Record48 of set3: mana
# Processing Record49 of set3: marion
# Processing Record50 of set3: longyan
# Processing Record0 of set4: srednekolymsk
# Processing Record1 of set4: severo-kurilsk
# Processing Record2 of set4: gat
# Processing Record3 of set4: aswan
# Processing Record4 of set4: komsomolskiy
# Processing Record5 of set4: beaupre
# Processing Record6 of set4: plainview
# Processing Record7 of set4: amargosa
# Processing Record8 of set4: tuktoyaktuk
# Processing Record9 of set4: rawson
# Processing Record10 of set4: catazaja
# Processing Record11 of set4: orlik
# Processing Record12 of set4: luderitz
# City not found. Skipping...
# City not found. Skipping...
# Processing Record13 of set4: muros
# Processing Record14 of set4: srivardhan
# City not found. Skipping...
# Processing Record15 of set4: sao joao da barra
# Processing Record16 of set4: souillac
# City not found. Skipping...
# Processing Record17 of set4: feldkirchen-westerham
# Processing Record18 of set4: coffs harbour
# Processing Record19 of set4: villanueva
# Processing Record20 of set4: narsaq
# Processing Record21 of set4: dakar
# Processing Record22 of set4: zhigalovo
# City not found. Skipping...
# Processing Record23 of set4: hidalgo
# Processing Record24 of set4: rabat
# Processing Record25 of set4: pandan
# Processing Record26 of set4: provideniya
# Processing Record27 of set4: saint-georges
# Processing Record28 of set4: shu
# Processing Record29 of set4: milkovo
# Processing Record30 of set4: yaviza
# Processing Record31 of set4: krasnoborsk
# Processing Record32 of set4: guerrero negro
# Processing Record33 of set4: kavaratti
# Processing Record34 of set4: sideropolis
# Processing Record35 of set4: amlame
# City not found. Skipping...
# Processing Record36 of set4: mugur-aksy
# Processing Record37 of set4: velingara
# Processing Record38 of set4: san patricio
# Processing Record39 of set4: lata
# Processing Record40 of set4: anadyr
# Processing Record41 of set4: sao fidelis
# Processing Record42 of set4: kolpashevo
# Processing Record43 of set4: meulaboh
# Processing Record44 of set4: neiafu
# Processing Record45 of set4: bandarbeyla
# Processing Record46 of set4: pacific grove
# City not found. Skipping...
# Processing Record47 of set4: hede
# Processing Record48 of set4: dodge city
# Processing Record49 of set4: madinat sittah uktubar
# Processing Record50 of set4: rabo de peixe
# Processing Record0 of set5: narragansett
# Processing Record1 of set5: hanyang
# Processing Record2 of set5: manadhoo
# Processing Record3 of set5: shahrud
# Processing Record4 of set5: saint anthony
# Processing Record5 of set5: grindavik
# Processing Record6 of set5: ladario
# Processing Record7 of set5: nantucket
# Processing Record8 of set5: fairbanks
# City not found. Skipping...
# Processing Record9 of set5: tucuman
# Processing Record10 of set5: sitka
# Processing Record11 of set5: yar-sale
# Processing Record12 of set5: wairoa
# City not found. Skipping...
# Processing Record13 of set5: hualmay
# Processing Record14 of set5: nikolskoye
# Processing Record15 of set5: west odessa
# Processing Record16 of set5: doka
# City not found. Skipping...
# Processing Record17 of set5: hami
# Processing Record18 of set5: victoria
# Processing Record19 of set5: petlawad
# Processing Record20 of set5: nanortalik
# Processing Record21 of set5: lebu
# Processing Record22 of set5: hobyo
# Processing Record23 of set5: beringovskiy
# Processing Record24 of set5: manggar
# Processing Record25 of set5: kaitangata
# Processing Record26 of set5: sokone
# Processing Record27 of set5: esperance
# Processing Record28 of set5: portobelo
# Processing Record29 of set5: filingue
# Processing Record30 of set5: khuzdar
# Processing Record31 of set5: emba
# City not found. Skipping...
# Processing Record32 of set5: mersing
# City not found. Skipping...
# Processing Record33 of set5: yulara
# Processing Record34 of set5: cocorit
# Processing Record35 of set5: karratha
# Processing Record36 of set5: yarim
# Processing Record37 of set5: shingu
# Processing Record38 of set5: korem
# Processing Record39 of set5: uige
# Processing Record40 of set5: jaffna
# Processing Record41 of set5: kavieng
# Processing Record42 of set5: pades
# Processing Record43 of set5: sur
# Processing Record44 of set5: emerald
# Processing Record45 of set5: simbahan
# Processing Record46 of set5: fukue
# Processing Record47 of set5: tingloy
# Processing Record48 of set5: tautira
# Processing Record49 of set5: conakry
# Processing Record50 of set5: mangrol
# Processing Record0 of set6: faya
# Processing Record1 of set6: namibe
# Processing Record2 of set6: abu kamal
# Processing Record3 of set6: rosario
# Processing Record4 of set6: urusha
# Processing Record5 of set6: abha
# Processing Record6 of set6: sao filipe
# Processing Record7 of set6: svetlyy
# Processing Record8 of set6: shahjahanpur
# Processing Record9 of set6: muli
# Processing Record10 of set6: yulin
# Processing Record11 of set6: vytegra
# Processing Record12 of set6: torbay
# Processing Record13 of set6: carlos chagas
# Processing Record14 of set6: the valley
# Processing Record15 of set6: khonsa
# Processing Record16 of set6: san ramon
# Processing Record17 of set6: caravelas
# Processing Record18 of set6: ilo
# Processing Record19 of set6: dunedin
# Processing Record20 of set6: te anau
# Processing Record21 of set6: saldanha
# Processing Record22 of set6: atar
# City not found. Skipping...
# Processing Record23 of set6: gazli
# Processing Record24 of set6: padang
# Processing Record25 of set6: bengkulu
# Processing Record26 of set6: pontes e lacerda
# City not found. Skipping...
# Processing Record27 of set6: vestmannaeyjar
# Processing Record28 of set6: carta
# Processing Record29 of set6: akyab
# Processing Record30 of set6: huanren
# City not found. Skipping...
# Processing Record31 of set6: bathsheba
# Processing Record32 of set6: xichang
# Processing Record33 of set6: jaisalmer
# City not found. Skipping...
# Processing Record34 of set6: terrasini
# Processing Record35 of set6: mount isa
# Processing Record36 of set6: serenje
# Processing Record37 of set6: vestmanna
# Processing Record38 of set6: pisco
# City not found. Skipping...
# Processing Record39 of set6: sisimiut
# Processing Record40 of set6: binga
# Processing Record41 of set6: cabedelo
# Processing Record42 of set6: lavrentiya
# Processing Record43 of set6: vardo
# Processing Record44 of set6: dingle
# Processing Record45 of set6: chulman
# Processing Record46 of set6: georgetown
# Processing Record47 of set6: maraba
# Processing Record48 of set6: cayenne
# Processing Record49 of set6: hamilton
# Processing Record50 of set6: valenza
# Processing Record0 of set7: asfi
# Processing Record1 of set7: garissa
# Processing Record2 of set7: dieppe
# Processing Record3 of set7: la libertad
# Processing Record4 of set7: kindu
# Processing Record5 of set7: conceicao do araguaia
# Processing Record6 of set7: iqaluit
# Processing Record7 of set7: genhe
# Processing Record8 of set7: santander
# Processing Record9 of set7: letpadan
# Processing Record10 of set7: balkhash
# Processing Record11 of set7: bad driburg
# Processing Record12 of set7: marystown
# Processing Record13 of set7: jatai
# Processing Record14 of set7: tolaga bay
# Processing Record15 of set7: mushie
# Processing Record16 of set7: thaton
# Processing Record17 of set7: patiya
# Processing Record18 of set7: bilma
# Processing Record19 of set7: jining
# Processing Record20 of set7: chokurdakh
# Processing Record21 of set7: kruisfontein
# City not found. Skipping...
# Processing Record22 of set7: arraial do cabo
# Processing Record23 of set7: fortuna
# Processing Record24 of set7: bonthe
# City not found. Skipping...
# Processing Record25 of set7: mingaora
# Processing Record26 of set7: klaksvik
# Processing Record27 of set7: laguna
# Processing Record28 of set7: mandalgovi
# Processing Record29 of set7: marrakesh
# Processing Record30 of set7: rock sound
# Processing Record31 of set7: cibitoke
# Processing Record32 of set7: el chichicaste
# Processing Record33 of set7: vila franca do campo
# City not found. Skipping...
# Processing Record34 of set7: kendari
# Processing Record35 of set7: sao joaquim
# Processing Record36 of set7: iralaya
# Processing Record37 of set7: rio gallegos
# Processing Record38 of set7: robertsport
# Processing Record39 of set7: pemba
# Processing Record40 of set7: golden gate
# Processing Record41 of set7: bubaque
# City not found. Skipping...
# Processing Record42 of set7: coahuayana
# Processing Record43 of set7: chernyshevskiy
# Processing Record44 of set7: krasnyy oktyabr
# Processing Record45 of set7: cururupu
# Processing Record46 of set7: erenhot
# Processing Record47 of set7: palanpur
# City not found. Skipping...
# Processing Record48 of set7: qui nhon
# Processing Record49 of set7: fort nelson
# Processing Record50 of set7: lalmohan
# Processing Record0 of set8: aklavik
# City not found. Skipping...
# Processing Record1 of set8: bondo
# Processing Record2 of set8: biharamulo
# Processing Record3 of set8: abu dhabi
# Processing Record4 of set8: progreso
# Processing Record5 of set8: san pedro
# Processing Record6 of set8: port moresby
# Processing Record7 of set8: netarhat
# Processing Record8 of set8: killybegs
# Processing Record9 of set8: mount gambier
# Processing Record10 of set8: talnakh
# City not found. Skipping...
# Processing Record11 of set8: wuda
# Processing Record12 of set8: berdigestyakh
# Processing Record13 of set8: montlucon
# Processing Record14 of set8: mahibadhoo
# Processing Record15 of set8: mercedes
# Processing Record16 of set8: coquimbo
# City not found. Skipping...
# Processing Record17 of set8: north bend
# Processing Record18 of set8: ixtapa
# Processing Record19 of set8: pavlodar
# Processing Record20 of set8: luba
# Processing Record21 of set8: batemans bay
# Processing Record22 of set8: poum
# Processing Record23 of set8: khani
# Processing Record24 of set8: cockburn town
# Processing Record25 of set8: galesong
# Processing Record26 of set8: ous
# Processing Record27 of set8: bryanka
# City not found. Skipping...
# Processing Record28 of set8: luau
# Processing Record29 of set8: come
# Processing Record30 of set8: luz
# Processing Record31 of set8: kaihua
# City not found. Skipping...
# Processing Record32 of set8: haines junction
# Processing Record33 of set8: nome
# Processing Record34 of set8: gujar khan
# Processing Record35 of set8: black river
# Processing Record36 of set8: charagua
# Processing Record37 of set8: praya
# City not found. Skipping...
# Processing Record38 of set8: songjianghe
# Processing Record39 of set8: trincomalee
# Processing Record40 of set8: tual
# Processing Record41 of set8: san cristobal
# Processing Record42 of set8: dwarka
# Processing Record43 of set8: riyadh
# City not found. Skipping...
# Processing Record44 of set8: naliya
# Processing Record45 of set8: shimanovsk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record46 of set8: derzhavinsk
# Processing Record47 of set8: kayes
# Processing Record48 of set8: morro bay
# Processing Record49 of set8: loubomo
# Processing Record50 of set8: kodiak
# Processing Record0 of set9: baruun-urt
# Processing Record1 of set9: port hawkesbury
# Processing Record2 of set9: rawah
# Processing Record3 of set9: machilipatnam
# City not found. Skipping...
# Processing Record4 of set9: vallenar
# Processing Record5 of set9: glendive
# Processing Record6 of set9: monster
# Processing Record7 of set9: vila velha
# Processing Record8 of set9: miraflores
# Processing Record9 of set9: quatre cocos
# Processing Record10 of set9: huamachuco
# Processing Record11 of set9: moose factory
# Processing Record12 of set9: zaysan
# Processing Record13 of set9: california city
# Processing Record14 of set9: grand gaube
# Processing Record15 of set9: tiruttani
# Processing Record16 of set9: acatlan
# Processing Record17 of set9: tonantins
# City not found. Skipping...
# Processing Record18 of set9: palmer
# Processing Record19 of set9: poronaysk
# Processing Record20 of set9: wanning
# Processing Record21 of set9: acapulco
# Processing Record22 of set9: vilyuysk
# Processing Record23 of set9: franca
# Processing Record24 of set9: majene
# Processing Record25 of set9: ponta delgada
# Processing Record26 of set9: gasa
# Processing Record27 of set9: virginia beach
# Processing Record28 of set9: sambava
# Processing Record29 of set9: saint-philippe
# Processing Record30 of set9: peterhead
# Processing Record31 of set9: sahuaripa
# Processing Record32 of set9: prince albert
# Processing Record33 of set9: veraval
# City not found. Skipping...
# Processing Record34 of set9: fare
# Processing Record35 of set9: dhidhdhoo
# Processing Record36 of set9: pasni
# Processing Record37 of set9: parabel
# Processing Record38 of set9: kanniyakumari
# Processing Record39 of set9: thinadhoo
# Processing Record40 of set9: lingyuan
# Processing Record41 of set9: tazovskiy
# Processing Record42 of set9: zhezkazgan
# Processing Record43 of set9: korla
# Processing Record44 of set9: longyearbyen
# Processing Record45 of set9: nambucca heads
# Processing Record46 of set9: belyy yar
# Processing Record47 of set9: constitucion
# Processing Record48 of set9: burgeo
# Processing Record49 of set9: zhangye
# Processing Record50 of set9: linhai
# Processing Record0 of set10: tombouctou
# Processing Record1 of set10: totoral
# City not found. Skipping...
# Processing Record2 of set10: klenovyy
# Processing Record3 of set10: yuanping
# Processing Record4 of set10: pemangkat
# Processing Record5 of set10: ejido hermosillo
# Processing Record6 of set10: kirakira
# Processing Record7 of set10: kati
# Processing Record8 of set10: kedrovyy
# Processing Record9 of set10: corn island
# Processing Record10 of set10: sechura
# Processing Record11 of set10: chokwe
# Processing Record12 of set10: geraldton
# Processing Record13 of set10: charters towers
# Processing Record14 of set10: saint-pierre
# Processing Record15 of set10: la asuncion
# Processing Record16 of set10: drummondville
# Processing Record17 of set10: drayton valley
# Processing Record18 of set10: champerico
# Processing Record19 of set10: sorland
# Processing Record20 of set10: prieska
# Processing Record21 of set10: samarai
# Processing Record22 of set10: toccoa
# Processing Record23 of set10: labuhan
# Processing Record24 of set10: doha
# Processing Record25 of set10: axim
# Processing Record26 of set10: imeni babushkina
# Processing Record27 of set10: rocha
# City not found. Skipping...
# Processing Record28 of set10: chertkovo
# Processing Record29 of set10: krasnovka
# Processing Record30 of set10: bako
# Processing Record31 of set10: russell
# Processing Record32 of set10: raudeberg
# Processing Record33 of set10: marawi
# Processing Record34 of set10: batagay-alyta
# Processing Record35 of set10: maldonado
# Processing Record36 of set10: mackay
# City not found. Skipping...
# Processing Record37 of set10: ilhabela
# Processing Record38 of set10: vila
# Processing Record39 of set10: chunar
# Processing Record40 of set10: gunnedah
# Processing Record41 of set10: nelson bay
# Processing Record42 of set10: tezu
# Processing Record43 of set10: bogalusa
# Processing Record44 of set10: krivodol
# Processing Record45 of set10: paamiut
# Processing Record46 of set10: bontang
# Processing Record47 of set10: kloulklubed
# Processing Record48 of set10: payo
# Processing Record49 of set10: jambi
# Processing Record50 of set10: lichinga
# Processing Record0 of set11: orikum
# Processing Record1 of set11: san jose
# Processing Record2 of set11: mairana
# Processing Record3 of set11: faanui
# Processing Record4 of set11: cahors
# Processing Record5 of set11: salalah
# Processing Record6 of set11: petropavlovsk-kamchatskiy
# Processing Record7 of set11: freeport
# Processing Record8 of set11: port-cartier
# Processing Record9 of set11: dukat
# Processing Record10 of set11: jablah
# Processing Record11 of set11: ilinskiy
# City not found. Skipping...
# Processing Record12 of set11: barreirinhas
# Processing Record13 of set11: marktheidenfeld
# City not found. Skipping...
# Processing Record14 of set11: zhoucheng
# Processing Record15 of set11: college
# Processing Record16 of set11: porto novo
# Processing Record17 of set11: oros
# City not found. Skipping...
# Processing Record18 of set11: buraydah
# Processing Record19 of set11: bradford
# Processing Record20 of set11: coulommiers
# Processing Record21 of set11: kiunga
# Processing Record22 of set11: topolobampo
# Processing Record23 of set11: chilca
# Processing Record24 of set11: makakilo city
# Processing Record25 of set11: contamana
# Processing Record26 of set11: uyuni
# Processing Record27 of set11: shuyskoye
# Processing Record28 of set11: belaya gora
# Processing Record29 of set11: tibati
# Processing Record30 of set11: porto murtinho
# City not found. Skipping...
# Processing Record31 of set11: grand island
# Processing Record32 of set11: barranca
# Processing Record33 of set11: birjand
# Processing Record34 of set11: salmo
# Processing Record35 of set11: limulunga
# Processing Record36 of set11: salvador
# Processing Record37 of set11: comodoro rivadavia
# Processing Record38 of set11: longkou
# Processing Record39 of set11: salym
# Processing Record40 of set11: antofagasta
# Processing Record41 of set11: hervey bay
# Processing Record42 of set11: eyl
# Processing Record43 of set11: kiama
# Processing Record44 of set11: sao felix do xingu
# Processing Record45 of set11: bull savanna
# Processing Record46 of set11: vazante
# Processing Record47 of set11: auki
# Processing Record48 of set11: vostok
# Processing Record49 of set11: chandler
# Processing Record50 of set11: kabinda
# Processing Record0 of set12: guiratinga
# Processing Record1 of set12: cortes
# Processing Record2 of set12: zlobin
# Processing Record3 of set12: parambu
# Processing Record4 of set12: el astillero
# Processing Record5 of set12: mehamn
# Processing Record6 of set12: flinders
# Processing Record7 of set12: lakatoro
# Processing Record8 of set12: taoudenni
# Processing Record9 of set12: saraland
# Processing Record10 of set12: northam
# Processing Record11 of set12: vengerovo
# City not found. Skipping...
# Processing Record12 of set12: ouesso
# -----------------------------
# Data Retrival Complete
# -----------------------------

# %% [markdown]
# # Convert Raw Data to DataFrame
#
# #### Export the city data into a .csv.
# #### Display the DataFrame

# %%
#Creating a dataframe with information received
Weather_pd = pd.DataFrame({
                        "City" : city_name_list, 
                        "Cloudiness" : cloudiness_list,
                        "Country" : country_list,
                        "Date" : data_list,
                        "Humidity" : humidity_list,
                        "Lat" : lat_list,
                        "Lon" : lon_list,
                        "Max Temp" : temp_max_list,
                        "Wind Speed" : wind_speed_list 
    
})

# %%
#Counting the data
Weather_pd.count()
# Out:
# City          573
# Cloudiness    573
# Country       573
# Date          573
# Humidity      573
# Lat           573
# Lon           573
# Max Temp      573
# Wind Speed    573
# dtype: int64

# %%
#Displaying the DataFrame
Weather_pd.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lon  \
# 0       Dikson           1      RU  1603930327        90  73.51   80.55
# 1        Lagoa           2      PT  1603930534        78  39.05  -27.98
# 2        Lahat         100      ID  1603930746        88  -3.80  103.53
# 3      Mataura          96      NZ  1603930494        76 -46.19  168.86
# 4  Yellowknife          96      CA  1603930450        97  62.46 -114.35
#
#    Max Temp  Wind Speed
# 0      3.06       22.59
# 1     65.32        9.82
# 2     74.98        1.68
# 3     57.99        4.00
# 4     23.00        3.24

# %%
#Export city data into a .CSV file
Weather_pd.to_csv("Output_data_file", index = False)

# %% [markdown]
# # Plotting the Data
#
# #### Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# #### Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Creating the Latitude vs. Temperature Scatter Plot

#Setting the plot title, xlabel, ylabel and grid
plt.title("City Latitude vs.Max Temperature(10/27/2020)", fontsize = 20)
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Max Temperature (F)", fontsize = 12)

plt.scatter(Weather_pd["Lat"],Weather_pd["Max Temp"], facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

#Saving the plot fig as .png
plt.savefig("../Images/City Latitude vs Max Temperature.png")

# %% [markdown]
# ###### As the Latitude is increasing the temperature drops

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Creating the Latitude vs. Humidity Scatter Plot

#Setting the plot title, xlabel, ylabel and grid
plt.title("City Latitude vs. Humidity(10/27/2020)", fontsize = 20)
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Humidity (%)", fontsize = 12)

plt.scatter(Weather_pd["Lat"],Weather_pd["Humidity"], facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()


#Saving the plot fig as .png
plt.savefig("../Images/City Latitude vs Humidity.png")

# %% [markdown]
# ###### As Latitude increases Humidity also increases

# %% [markdown]
# ##  Latitude vs. Cloudiness Plot

# %%
#Creating the Latitude vs. Cloudiness Scatter Plot

#Setting the plot title, xlabel, ylabel and grid
plt.title("City Latitude vs. Cloudiness(10/27/2020)", fontsize = 20)
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Cloudiness (%)", fontsize = 12)

plt.scatter(Weather_pd["Lat"],Weather_pd["Cloudiness"], facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

#Saving the plot fig as .png
plt.savefig("../Images/City Latitude vs Cloudiness.png")

# %% [markdown]
# ###### City cloudiness is spread all over the latitude

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Creating the Latitude vs. Wind Speed Scatter Plot

#Setting the plot title, xlabel, ylabel and grid
plt.title("City Latitude vs. Wind Speed(10/27/2020)", fontsize = 20)
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Wind Speed (mph)", fontsize = 12)

plt.scatter(Weather_pd["Lat"],Weather_pd["Wind Speed"], facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

#Saving the plot fig as .png
plt.savefig("../Images/City Latitude vs Wind Speed.png")

# %% [markdown]
# ###### As the laitude increases, Wind speed is spreading at same mph

# %% [markdown]
# #  Linear Regression

# %%
#Creating DataFrame for Northern Henisphere and Southern Hemisphere
southern_hemisphere = Weather_pd.loc[Weather_pd["Lat"]<0]
northern_hemisphere = Weather_pd.loc[Weather_pd["Lat"]>=0]

# %% [markdown]
# ##  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Creating linear regression and scatter plots
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Max Temp vs Latitude Linear Regression(Northern Hemisphere)", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (10,20), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Max Temp", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

#Saving the plot fig as .png
plt.savefig("../Images/Temperatues at Latitude Positions(Northern Hemisphere.png")

# %% [markdown]
# ###### The plot shows negative correlation between Max Temp and Latitude in Northern Hemisphere

# %% [markdown]
# ##  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Max Temp vs Latitude Linear Regression(Southern Hemisphere)", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (-20,5), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Max Temp", fontsize = 12)
plt.xlim = (0, -60)
plt.ylim = (40, 100)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

#Saving the plot fig as .png
plt.savefig("../Images/Temperatues at Latitude Positions(Southern Hemisphere.png")

# %% [markdown]
# ###### The plot shows positive correlation between Max Temp and Latitude in Southern Hemisphere

# %% [markdown]
# ## Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (50,20), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Humidity (%)", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

#Saving the plot fig as .png
plt.savefig("../Images/Northern Hemisphere - Humidity (%) vs. Latitude.png")

# %% [markdown]
# ##### The plot shows moderate positive correlation between Humidity(%) and Latitude in Northern Hemisphere

# %% [markdown]
# ##  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (-20,20), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Humidity (%)", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

#Saving the plot fig as .png
plt.savefig("../Images/Southern Hemisphere - Humidity (%) vs. Latitude.png")

# %% [markdown]
# ##### The plot shows moderate positive correlation between Humidity(%) and Latitude in Southern Hemisphere

# %% [markdown]
# ## Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (10,20), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Cloudiness (%)", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

#Saving the plot fig as .png
plt.savefig("../Images/Northern Hemisphere - Cloudiness (%) vs. Latitude.png")

# %% [markdown]
# ##### The plot shows moderate positive correlation between Cloudiness(%) and Latitude in Northern Hemisphere

# %% [markdown]
# ## Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (-50,80), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Cloudiness (%)", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

#Saving the plot fig as .png
plt.savefig("../Images/Southern Hemisphere - Cloudiness (%) vs. Latitude.png")

# %% [markdown]
# ##### The plot shows positive correlation between Humidity(%) and Latitude in Southern Hemisphere

# %% [markdown]
# ## Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Northern Hemisphere - Wind Speed(mph) vs. Latitude", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (60,10), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Wind Speed", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

#Saving the plot fig as .png
plt.savefig("../Images/Northern Hemisphere - Wind Speed(mph) vs. Latitude.png")

# %% [markdown]
# ##### The plot shows moderate positive correlation between Wind Speed(mph) and Latitude in Northern Hemisphere

# %% [markdown]
# ## Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Southern Hemisphere - Wind Speed(mph) vs. Latitude", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (-50,8), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Wind Speed(mph)", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

#Saving the plot fig as .png
plt.savefig("../Images/Southern Hemisphere - Wind Speed(mph) vs. Latitude.png")

# %% [markdown]
# ##### The plot shows negative correlation between Wind Speed(mph) and Latitude in Southern Hemisphere

# %% [markdown]
# ##### Observations

# %% [markdown]
# ##### 1.Maximum temperature and Latitude work differently in Northern Hemishpere amd Southern Hemisphere. In Northern Hemishpere, max temperature and latitude are negatively correlated, which means that if the latitude increase max temperature decreases. Whereas in southern hemisphere its vice versa
#
# ##### 2.Cloudiness (%) and Latitude work similarly in both Northern Hemishpere amd Southern Hemisphere. The relation between cloudiness and latitude is moderately positively correlated in both hemispheres, which means as the latitude increases, the cloudiness also increases.
#
# ##### 3.For all the cities analyzed in the scatter plot, the cloudiness seem to be spead around all the latitude.
