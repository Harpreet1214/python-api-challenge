# %%
#Dependencies and Setup
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
from scipy.stats import linregress
import scipy.stats as st

# %%
# Import API key
from config import weather_api_key

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\gagans\desktop\bootcamp\bootcamp\lib\site-packages (0.0.5)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: kdtree>=0.12 in c:\users\gagans\desktop\bootcamp\bootcamp\lib\site-packages (from citipy) (0.16)
# WARNING: You are using pip version 20.1.1; however, version 20.2.4 is available.
# You should consider upgrading via the 'c:\users\gagans\desktop\bootcamp\bootcamp\scripts\python.exe -m pip install --upgrade pip' command.

# %%
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
# Output File (CSV)
Output_data_file = "output_data/cities.csv"

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# # Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 606

# %% [markdown]
# #  Perform API Calls
#
# #### Perform a weather check on each city using a series of successive API calls.
# #### Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print("Beginning Data Retrieval")
print("-------------------------------")

#Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

#Build query url
endpoint = f"{url}appid={weather_api_key}&units={units}&q="

#Creating the response and store in json
#response = requests.get(url).json()

#Set empty list to hold each city's characteristics
city_name_list = []
cloudiness_list = []
country_list = []
data_list = []
humidity_list = []
lat_list = []
lon_list = []
temp_max_list = []
wind_speed_list = []
index_counter = 0
set_counter = 1


#Try to get the city data that is available in the OpenWeather API
for index, city in enumerate (cities, start = 1):
    try:
        response = requests.get(endpoint + city).json()
        city_name_list.append(response["name"])
        cloudiness_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        data_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lat_list.append(response["coord"]["lat"])
        lon_list.append(response["coord"]["lon"])
        temp_max_list.append(response["main"]["temp_max"])
        wind_speed_list.append(response["wind"]["speed"])

        
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
        
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record{index_counter} of set{set_counter}: {city}")
           
        
    except KeyError:
            print("City not found. Skipping...")
            
print("-----------------------------")
print("Data Retrival Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record1 of set1: nadym
# Processing Record2 of set1: tasiilaq
# Processing Record3 of set1: east london
# Processing Record4 of set1: busselton
# Processing Record5 of set1: roma
# Processing Record6 of set1: wattegama
# Processing Record7 of set1: bluff
# Processing Record8 of set1: alofi
# Processing Record9 of set1: hermanus
# City not found. Skipping...
# Processing Record10 of set1: bethel
# Processing Record11 of set1: cape town
# Processing Record12 of set1: mahebourg
# Processing Record13 of set1: vao
# Processing Record14 of set1: butaritari
# Processing Record15 of set1: san policarpo
# Processing Record16 of set1: wloszczowa
# Processing Record17 of set1: vaini
# Processing Record18 of set1: tuktoyaktuk
# Processing Record19 of set1: punta arenas
# City not found. Skipping...
# Processing Record20 of set1: kodiak
# Processing Record21 of set1: bredasdorp
# Processing Record22 of set1: mikuni
# Processing Record23 of set1: cockburn town
# City not found. Skipping...
# Processing Record24 of set1: kalocsa
# Processing Record25 of set1: sinegorye
# Processing Record26 of set1: hobart
# Processing Record27 of set1: bandarbeyla
# City not found. Skipping...
# Processing Record28 of set1: moron
# Processing Record29 of set1: verkhoyansk
# Processing Record30 of set1: port-gentil
# Processing Record31 of set1: kaitangata
# Processing Record32 of set1: pevek
# Processing Record33 of set1: gat
# Processing Record34 of set1: mount isa
# Processing Record35 of set1: manokwari
# Processing Record36 of set1: port elizabeth
# Processing Record37 of set1: cidreira
# Processing Record38 of set1: sioux lookout
# Processing Record39 of set1: mnogovershinnyy
# Processing Record40 of set1: migori
# Processing Record41 of set1: qaanaaq
# Processing Record42 of set1: victoria
# Processing Record43 of set1: olinda
# Processing Record44 of set1: rikitea
# Processing Record45 of set1: hilo
# Processing Record46 of set1: luino
# Processing Record47 of set1: marigot
# Processing Record48 of set1: beloha
# Processing Record49 of set1: castro
# Processing Record50 of set1: presque isle
# City not found. Skipping...
# Processing Record0 of set2: hermiston
# Processing Record1 of set2: ahipara
# Processing Record2 of set2: saint-francois
# Processing Record3 of set2: petropavlovsk-kamchatskiy
# Processing Record4 of set2: mataura
# Processing Record5 of set2: kayes
# Processing Record6 of set2: nyurba
# Processing Record7 of set2: grand-santi
# Processing Record8 of set2: ushuaia
# Processing Record9 of set2: hofn
# Processing Record10 of set2: meulaboh
# City not found. Skipping...
# Processing Record11 of set2: panguipulli
# Processing Record12 of set2: iqaluit
# Processing Record13 of set2: touros
# Processing Record14 of set2: rodrigues alves
# City not found. Skipping...
# City not found. Skipping...
# Processing Record15 of set2: taltal
# Processing Record16 of set2: goderich
# Processing Record17 of set2: katobu
# Processing Record18 of set2: autazes
# Processing Record19 of set2: jamestown
# Processing Record20 of set2: tshela
# Processing Record21 of set2: nelson bay
# Processing Record22 of set2: rocha
# Processing Record23 of set2: mersing
# Processing Record24 of set2: gazanjyk
# Processing Record25 of set2: atuona
# Processing Record26 of set2: bemidji
# Processing Record27 of set2: barrow
# Processing Record28 of set2: hithadhoo
# Processing Record29 of set2: caravelas
# Processing Record30 of set2: nikolskoye
# Processing Record31 of set2: puerto ayora
# Processing Record32 of set2: kamenka
# Processing Record33 of set2: fort saint james
# Processing Record34 of set2: codrington
# Processing Record35 of set2: souillac
# Processing Record36 of set2: westport
# City not found. Skipping...
# Processing Record37 of set2: upernavik
# Processing Record38 of set2: junin
# Processing Record39 of set2: airai
# Processing Record40 of set2: puerto escondido
# Processing Record41 of set2: mar del plata
# Processing Record42 of set2: albany
# Processing Record43 of set2: muros
# Processing Record44 of set2: sinnamary
# Processing Record45 of set2: vardo
# Processing Record46 of set2: bengkulu
# Processing Record47 of set2: dikson
# Processing Record48 of set2: yellowknife
# Processing Record49 of set2: presidencia roque saenz pena
# Processing Record50 of set2: carnarvon
# Processing Record0 of set3: pachino
# Processing Record1 of set3: beisfjord
# Processing Record2 of set3: kapaa
# Processing Record3 of set3: saint george
# Processing Record4 of set3: atar
# Processing Record5 of set3: kavaratti
# Processing Record6 of set3: kavieng
# Processing Record7 of set3: paamiut
# Processing Record8 of set3: cheremukhovo
# Processing Record9 of set3: shingu
# Processing Record10 of set3: fortuna
# City not found. Skipping...
# Processing Record11 of set3: khanpur
# Processing Record12 of set3: longyearbyen
# Processing Record13 of set3: tucuman
# Processing Record14 of set3: ust-kan
# Processing Record15 of set3: martapura
# Processing Record16 of set3: flinders
# City not found. Skipping...
# Processing Record17 of set3: lerwick
# City not found. Skipping...
# Processing Record18 of set3: brigantine
# Processing Record19 of set3: salalah
# City not found. Skipping...
# Processing Record20 of set3: havelock
# Processing Record21 of set3: boyabat
# Processing Record22 of set3: biryusinsk
# Processing Record23 of set3: laranjeiras do sul
# Processing Record24 of set3: limanowa
# Processing Record25 of set3: mount gambier
# City not found. Skipping...
# Processing Record26 of set3: saint-louis
# Processing Record27 of set3: arteaga
# Processing Record28 of set3: anadyr
# Processing Record29 of set3: walvis bay
# Processing Record30 of set3: yenagoa
# Processing Record31 of set3: macas
# Processing Record32 of set3: bukama
# Processing Record33 of set3: geraldton
# Processing Record34 of set3: chuy
# Processing Record35 of set3: cavalcante
# Processing Record36 of set3: ponta do sol
# Processing Record37 of set3: sao filipe
# Processing Record38 of set3: scarborough
# Processing Record39 of set3: leningradskiy
# Processing Record40 of set3: port alfred
# Processing Record41 of set3: abu dhabi
# Processing Record42 of set3: jiazi
# Processing Record43 of set3: puerto ayacucho
# City not found. Skipping...
# Processing Record44 of set3: ketchikan
# City not found. Skipping...
# Processing Record45 of set3: hasaki
# Processing Record46 of set3: contamana
# Processing Record47 of set3: saint-philippe
# Processing Record48 of set3: hobyo
# Processing Record49 of set3: elmira
# Processing Record50 of set3: khatanga
# Processing Record0 of set4: banda aceh
# Processing Record1 of set4: tura
# Processing Record2 of set4: umm lajj
# City not found. Skipping...
# Processing Record3 of set4: severo-kurilsk
# Processing Record4 of set4: osypenko
# City not found. Skipping...
# Processing Record5 of set4: avarua
# Processing Record6 of set4: boende
# Processing Record7 of set4: bolshaya rechka
# Processing Record8 of set4: sitka
# Processing Record9 of set4: maniitsoq
# Processing Record10 of set4: tabas
# Processing Record11 of set4: keita
# Processing Record12 of set4: florianopolis
# Processing Record13 of set4: itape
# Processing Record14 of set4: karratha
# Processing Record15 of set4: nanortalik
# Processing Record16 of set4: ribeira grande
# Processing Record17 of set4: sao joao da barra
# Processing Record18 of set4: batemans bay
# Processing Record19 of set4: arraial do cabo
# Processing Record20 of set4: port hedland
# Processing Record21 of set4: la rioja
# Processing Record22 of set4: leh
# Processing Record23 of set4: sao felix do xingu
# Processing Record24 of set4: tiksi
# Processing Record25 of set4: south lake tahoe
# Processing Record26 of set4: praia da vitoria
# Processing Record27 of set4: sisimiut
# Processing Record28 of set4: viedma
# Processing Record29 of set4: sitio novo do tocantins
# Processing Record30 of set4: luwingu
# Processing Record31 of set4: dunedin
# Processing Record32 of set4: oeiras
# Processing Record33 of set4: morondava
# Processing Record34 of set4: georgetown
# Processing Record35 of set4: spornoye
# Processing Record36 of set4: deputatskiy
# Processing Record37 of set4: talcahuano
# Processing Record38 of set4: belyy yar
# Processing Record39 of set4: batagay
# Processing Record40 of set4: maracas
# Processing Record41 of set4: lata
# Processing Record42 of set4: general roca
# Processing Record43 of set4: koscian
# Processing Record44 of set4: carman
# City not found. Skipping...
# City not found. Skipping...
# Processing Record45 of set4: kieta
# Processing Record46 of set4: chokurdakh
# Processing Record47 of set4: majene
# Processing Record48 of set4: kiama
# Processing Record49 of set4: cherskiy
# Processing Record50 of set4: garden city
# Processing Record0 of set5: kalulushi
# Processing Record1 of set5: bourail
# Processing Record2 of set5: faanui
# Processing Record3 of set5: caraballeda
# Processing Record4 of set5: seddon
# Processing Record5 of set5: singapore
# City not found. Skipping...
# Processing Record6 of set5: loukhi
# Processing Record7 of set5: saskylakh
# Processing Record8 of set5: ratlam
# Processing Record9 of set5: pacific grove
# City not found. Skipping...
# Processing Record10 of set5: bamiantong
# Processing Record11 of set5: lazaro cardenas
# City not found. Skipping...
# Processing Record12 of set5: bambous virieux
# Processing Record13 of set5: halifax
# Processing Record14 of set5: komsomolskiy
# Processing Record15 of set5: lebu
# Processing Record16 of set5: olonets
# Processing Record17 of set5: thompson
# Processing Record18 of set5: lishan
# Processing Record19 of set5: akhnur
# City not found. Skipping...
# Processing Record20 of set5: mehamn
# Processing Record21 of set5: vilyuysk
# City not found. Skipping...
# Processing Record22 of set5: virginia beach
# Processing Record23 of set5: serov
# Processing Record24 of set5: peniche
# Processing Record25 of set5: fare
# Processing Record26 of set5: richards bay
# Processing Record27 of set5: talnakh
# Processing Record28 of set5: cayenne
# Processing Record29 of set5: zhigansk
# Processing Record30 of set5: eyl
# Processing Record31 of set5: toro
# Processing Record32 of set5: new norfolk
# City not found. Skipping...
# Processing Record33 of set5: nagaur
# Processing Record34 of set5: ilulissat
# Processing Record35 of set5: klaksvik
# Processing Record36 of set5: vrutky
# City not found. Skipping...
# Processing Record37 of set5: palmer
# Processing Record38 of set5: nieuw amsterdam
# Processing Record39 of set5: bor
# Processing Record40 of set5: kamakwie
# Processing Record41 of set5: chicama
# Processing Record42 of set5: blackwater
# City not found. Skipping...
# Processing Record43 of set5: isangel
# Processing Record44 of set5: amambai
# Processing Record45 of set5: dakoro
# Processing Record46 of set5: antofagasta
# Processing Record47 of set5: bunol
# City not found. Skipping...
# Processing Record48 of set5: siguiri
# Processing Record49 of set5: lillooet
# City not found. Skipping...
# Processing Record50 of set5: pio xii
# Processing Record0 of set6: kinablangan
# Processing Record1 of set6: chateaudun
# Processing Record2 of set6: barcelos
# Processing Record3 of set6: inverness
# City not found. Skipping...
# Processing Record4 of set6: narsaq
# Processing Record5 of set6: jabinyanah
# Processing Record6 of set6: kapit
# Processing Record7 of set6: norman wells
# Processing Record8 of set6: batagay-alyta
# City not found. Skipping...
# Processing Record9 of set6: alugan
# Processing Record10 of set6: dickinson
# Processing Record11 of set6: adre
# City not found. Skipping...
# Processing Record12 of set6: dudinka
# City not found. Skipping...
# Processing Record13 of set6: yoichi
# Processing Record14 of set6: brownsville
# Processing Record15 of set6: matara
# Processing Record16 of set6: fredericton
# Processing Record17 of set6: coihaique
# Processing Record18 of set6: luderitz
# City not found. Skipping...
# Processing Record19 of set6: bathsheba
# Processing Record20 of set6: naze
# Processing Record21 of set6: katherine
# Processing Record22 of set6: teshie
# Processing Record23 of set6: belaya gora
# City not found. Skipping...
# Processing Record24 of set6: sept-iles
# Processing Record25 of set6: kapoeta
# Processing Record26 of set6: san jose
# Processing Record27 of set6: nantucket
# Processing Record28 of set6: barquisimeto
# Processing Record29 of set6: saldanha
# Processing Record30 of set6: bhuban
# Processing Record31 of set6: maragogi
# Processing Record32 of set6: ostrovnoy
# Processing Record33 of set6: arlit
# Processing Record34 of set6: lompoc
# Processing Record35 of set6: bubaque
# Processing Record36 of set6: biograd na moru
# Processing Record37 of set6: half moon bay
# Processing Record38 of set6: namatanai
# Processing Record39 of set6: gloversville
# Processing Record40 of set6: butembo
# Processing Record41 of set6: vila franca do campo
# Processing Record42 of set6: ambilobe
# Processing Record43 of set6: horsham
# Processing Record44 of set6: shenjiamen
# Processing Record45 of set6: minot
# Processing Record46 of set6: loei
# City not found. Skipping...
# Processing Record47 of set6: blagoyevo
# Processing Record48 of set6: picton
# Processing Record49 of set6: saint anthony
# Processing Record50 of set6: kattivakkam
# Processing Record0 of set7: mogadishu
# Processing Record1 of set7: robertsport
# Processing Record2 of set7: whitehorse
# Processing Record3 of set7: luba
# Processing Record4 of set7: zinder
# Processing Record5 of set7: coroico
# Processing Record6 of set7: marawi
# Processing Record7 of set7: lagoa
# Processing Record8 of set7: kangaatsiaq
# Processing Record9 of set7: luanda
# Processing Record10 of set7: grindavik
# Processing Record11 of set7: aklavik
# Processing Record12 of set7: kloulklubed
# Processing Record13 of set7: jian
# Processing Record14 of set7: mazatlan
# City not found. Skipping...
# Processing Record15 of set7: krasnoselkup
# Processing Record16 of set7: auki
# Processing Record17 of set7: zlobin
# Processing Record18 of set7: santa cruz cabralia
# Processing Record19 of set7: iquique
# City not found. Skipping...
# Processing Record20 of set7: chornobay
# Processing Record21 of set7: lorengau
# Processing Record22 of set7: shiraoi
# Processing Record23 of set7: hami
# Processing Record24 of set7: husavik
# Processing Record25 of set7: emerald
# Processing Record26 of set7: provideniya
# Processing Record27 of set7: tautira
# Processing Record28 of set7: kahului
# Processing Record29 of set7: goma
# Processing Record30 of set7: pedernales
# Processing Record31 of set7: raudeberg
# Processing Record32 of set7: te anau
# Processing Record33 of set7: buturlinovka
# Processing Record34 of set7: toora-khem
# Processing Record35 of set7: piacabucu
# Processing Record36 of set7: zarechnyy
# Processing Record37 of set7: macau
# Processing Record38 of set7: jaen
# Processing Record39 of set7: maua
# Processing Record40 of set7: ibra
# Processing Record41 of set7: quatre cocos
# Processing Record42 of set7: kyabe
# Processing Record43 of set7: kambam
# Processing Record44 of set7: amahai
# Processing Record45 of set7: basar
# Processing Record46 of set7: inuvik
# Processing Record47 of set7: shache
# Processing Record48 of set7: baykalsk
# Processing Record49 of set7: vestmannaeyjar
# Processing Record50 of set7: padang
# Processing Record0 of set8: clyde river
# Processing Record1 of set8: takoradi
# Processing Record2 of set8: vlasim
# Processing Record3 of set8: qaqortoq
# Processing Record4 of set8: san cristobal
# Processing Record5 of set8: san jeronimo
# Processing Record6 of set8: dongli
# Processing Record7 of set8: karpathos
# Processing Record8 of set8: stornoway
# Processing Record9 of set8: srednekolymsk
# Processing Record10 of set8: martinsburg
# Processing Record11 of set8: torbay
# Processing Record12 of set8: washington
# Processing Record13 of set8: napasar
# Processing Record14 of set8: dondo
# Processing Record15 of set8: christchurch
# Processing Record16 of set8: sao jose da coroa grande
# Processing Record17 of set8: inta
# Processing Record18 of set8: khandyga
# Processing Record19 of set8: san patricio
# Processing Record20 of set8: los llanos de aridane
# Processing Record21 of set8: artigas
# Processing Record22 of set8: coquimbo
# Processing Record23 of set8: marienburg
# Processing Record24 of set8: korla
# Processing Record25 of set8: uthal
# Processing Record26 of set8: baoying
# Processing Record27 of set8: fagaras
# Processing Record28 of set8: russell
# Processing Record29 of set8: leiyang
# Processing Record30 of set8: kruisfontein
# Processing Record31 of set8: hamilton
# Processing Record32 of set8: esperance
# Processing Record33 of set8: puerto baquerizo moreno
# Processing Record34 of set8: aasiaat
# Processing Record35 of set8: uetendorf
# Processing Record36 of set8: evensk
# Processing Record37 of set8: port macquarie
# Processing Record38 of set8: sola
# Processing Record39 of set8: opuwo
# Processing Record40 of set8: katsuura
# Processing Record41 of set8: songadh
# City not found. Skipping...
# Processing Record42 of set8: tooele
# Processing Record43 of set8: minden
# Processing Record44 of set8: wharton
# Processing Record45 of set8: guia de isora
# Processing Record46 of set8: prince rupert
# Processing Record47 of set8: upington
# Processing Record48 of set8: homer
# Processing Record49 of set8: buala
# City not found. Skipping...
# Processing Record50 of set8: remedios
# Processing Record0 of set9: port hawkesbury
# Processing Record1 of set9: sabang
# City not found. Skipping...
# Processing Record2 of set9: diapaga
# Processing Record3 of set9: manggar
# Processing Record4 of set9: flagstaff
# Processing Record5 of set9: barroso
# Processing Record6 of set9: nara
# Processing Record7 of set9: dilla
# Processing Record8 of set9: kachug
# Processing Record9 of set9: roald
# Processing Record10 of set9: thinadhoo
# Processing Record11 of set9: san andres
# Processing Record12 of set9: biltine
# Processing Record13 of set9: omboue
# Processing Record14 of set9: sulam
# Processing Record15 of set9: sao desiderio
# Processing Record16 of set9: benguela
# City not found. Skipping...
# Processing Record17 of set9: sabha
# Processing Record18 of set9: makakilo city
# Processing Record19 of set9: sotouboua
# Processing Record20 of set9: coahuayana
# Processing Record21 of set9: ust-kuyga
# Processing Record22 of set9: port blair
# Processing Record23 of set9: kruszwica
# Processing Record24 of set9: sangar
# Processing Record25 of set9: lavrentiya
# Processing Record26 of set9: abbeville
# Processing Record27 of set9: chikmagalur
# Processing Record28 of set9: praxedis guerrero
# Processing Record29 of set9: tucumcari
# Processing Record30 of set9: alihe
# Processing Record31 of set9: bonnyville
# Processing Record32 of set9: mao
# Processing Record33 of set9: curuca
# Processing Record34 of set9: sakakah
# Processing Record35 of set9: linhares
# Processing Record36 of set9: pisco
# Processing Record37 of set9: tomatlan
# Processing Record38 of set9: khuzdar
# Processing Record39 of set9: murray bridge
# Processing Record40 of set9: chabahar
# Processing Record41 of set9: kharp
# Processing Record42 of set9: tallahassee
# Processing Record43 of set9: yeppoon
# City not found. Skipping...
# Processing Record44 of set9: kushima
# Processing Record45 of set9: broken hill
# Processing Record46 of set9: orlik
# Processing Record47 of set9: skibbereen
# Processing Record48 of set9: yulara
# Processing Record49 of set9: havoysund
# Processing Record50 of set9: udachnyy
# Processing Record0 of set10: portland
# Processing Record1 of set10: iwaki
# Processing Record2 of set10: najran
# Processing Record3 of set10: vanavara
# Processing Record4 of set10: mandalgovi
# Processing Record5 of set10: mugur-aksy
# Processing Record6 of set10: corowa
# Processing Record7 of set10: bastrop
# Processing Record8 of set10: taoudenni
# City not found. Skipping...
# Processing Record9 of set10: hereford
# Processing Record10 of set10: nouadhibou
# Processing Record11 of set10: yar-sale
# Processing Record12 of set10: skarnes
# Processing Record13 of set10: shahreza
# Processing Record14 of set10: merauke
# Processing Record15 of set10: kirakira
# Processing Record16 of set10: ust-nera
# Processing Record17 of set10: nushki
# Processing Record18 of set10: tilichiki
# Processing Record19 of set10: montepuez
# Processing Record20 of set10: kijang
# Processing Record21 of set10: corinto
# Processing Record22 of set10: nambucca heads
# Processing Record23 of set10: yatou
# Processing Record24 of set10: nome
# Processing Record25 of set10: karaton
# Processing Record26 of set10: cananeia
# Processing Record27 of set10: gravdal
# Processing Record28 of set10: ponta delgada
# Processing Record29 of set10: atambua
# Processing Record30 of set10: olafsvik
# Processing Record31 of set10: inirida
# Processing Record32 of set10: tuatapere
# Processing Record33 of set10: flin flon
# Processing Record34 of set10: mercedes
# Processing Record35 of set10: ahuimanu
# Processing Record36 of set10: maumere
# Processing Record37 of set10: mayo
# Processing Record38 of set10: visby
# Processing Record39 of set10: dongzhen
# Processing Record40 of set10: tymovskoye
# Processing Record41 of set10: sayat
# Processing Record42 of set10: valle de allende
# Processing Record43 of set10: buraydah
# Processing Record44 of set10: mareeba
# Processing Record45 of set10: bogovarovo
# Processing Record46 of set10: kununurra
# Processing Record47 of set10: naron
# Processing Record48 of set10: mulanje
# Processing Record49 of set10: zhezkazgan
# Processing Record50 of set10: taloqan
# Processing Record0 of set11: poya
# Processing Record1 of set11: promyshlennovskiy
# Processing Record2 of set11: kargasok
# Processing Record3 of set11: huilong
# Processing Record4 of set11: chapais
# Processing Record5 of set11: tual
# Processing Record6 of set11: powell river
# Processing Record7 of set11: hovd
# Processing Record8 of set11: kalmunai
# Processing Record9 of set11: tezu
# Processing Record10 of set11: aksarka
# Processing Record11 of set11: krasnoye
# Processing Record12 of set11: nuuk
# Processing Record13 of set11: avera
# Processing Record14 of set11: staryy nadym
# Processing Record15 of set11: pyu
# Processing Record16 of set11: vegreville
# Processing Record17 of set11: magnitka
# Processing Record18 of set11: cravo norte
# Processing Record19 of set11: pontal do parana
# Processing Record20 of set11: barra do pirai
# City not found. Skipping...
# Processing Record21 of set11: pochutla
# Processing Record22 of set11: odweyne
# City not found. Skipping...
# Processing Record23 of set11: dingle
# Processing Record24 of set11: inhambane
# Processing Record25 of set11: kiyasovo
# Processing Record26 of set11: smolensk
# Processing Record27 of set11: bertoua
# Processing Record28 of set11: raja sansi
# Processing Record29 of set11: acarau
# Processing Record30 of set11: talkha
# Processing Record31 of set11: zig
# City not found. Skipping...
# Processing Record32 of set11: thayetmyo
# City not found. Skipping...
# Processing Record33 of set11: prince george
# Processing Record34 of set11: kharitonovo
# Processing Record35 of set11: genc
# Processing Record36 of set11: libreville
# Processing Record37 of set11: harper
# Processing Record38 of set11: yantzaza
# Processing Record39 of set11: salamiyah
# Processing Record40 of set11: dustlik
# Processing Record41 of set11: kirundo
# Processing Record42 of set11: mateare
# Processing Record43 of set11: acapulco
# Processing Record44 of set11: paramonga
# Processing Record45 of set11: ibiruba
# Processing Record46 of set11: manono
# Processing Record47 of set11: agirish
# -----------------------------
# Data Retrival Complete
# -----------------------------

# %% [markdown]
# # Convert Raw Data to DataFrame
#
# #### Export the city data into a .csv.
# #### Display the DataFrame

# %%
#Creating a dataframe with information received
Weather_pd = pd.DataFrame({
                        "City" : city_name_list, 
                        "Cloudiness" : cloudiness_list,
                        "Country" : country_list,
                        "Date" : data_list,
                        "Humidity" : humidity_list,
                        "Lat" : lat_list,
                        "Lon" : lon_list,
                        "Max Temp" : temp_max_list,
                        "Wind Speed" : wind_speed_list 
    
})

# %%
#Counting the data
Weather_pd.count()
# Out:
# City          557
# Cloudiness    557
# Country       557
# Date          557
# Humidity      557
# Lat           557
# Lon           557
# Max Temp      557
# Wind Speed    557
# dtype: int64

# %%
#Displaying the DataFrame
Weather_pd.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lon  \
# 0        Nadym           0      RU  1603849423        90  65.53   72.52
# 1     Tasiilaq         100      GL  1603849424        37  65.61  -37.64
# 2  East London          50      ZA  1603849424        75 -33.02   27.91
# 3    Busselton          25      AU  1603849281        71 -33.65  115.33
# 4         Rome          90      US  1603849174        86  43.21  -75.46
#
#    Max Temp  Wind Speed
# 0      1.33        6.06
# 1     33.80       19.46
# 2     66.87       16.22
# 3     64.00        1.99
# 4     41.00        1.57

# %%
#Export city data into a .CSV file
Weather_pd.to_csv("Output_data_file", index = False)

# %% [markdown]
# # Plotting the Data
#
# #### Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# #### Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Creating the Latitude vs. Temperature Scatter Plot

plt.title("City Latitude vs.Max Temperature(10/27/2020)", fontsize = 20)
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Max Temperature (F)", fontsize = 12)

plt.scatter(Weather_pd["Lat"],Weather_pd["Max Temp"], facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

plt.savefig("../Images/City Latitude vs.Max Temperature.png")

# %% [markdown]
# ###### As the Latitude is increasing the temperature drops

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Creating the Latitude vs. Humidity Scatter Plot

plt.title("City Latitude vs. Humidity(10/27/2020)", fontsize = 20)
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Humidity (%)", fontsize = 12)

plt.scatter(Weather_pd["Lat"],Weather_pd["Humidity"], facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

plt.savefig("../Images/City Latitude vs.Humidity.png")

# %% [markdown]
# ###### As Latitude increases Humidity also increases

# %% [markdown]
# ##  Latitude vs. Cloudiness Plot

# %%
#Creating the Latitude vs. Cloudiness Scatter Plot

plt.title("City Latitude vs. Cloudiness(10/27/2020)", fontsize = 20)
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Cloudiness (%)", fontsize = 12)

plt.scatter(Weather_pd["Lat"],Weather_pd["Cloudiness"], facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

plt.savefig("../Images/City Latitude vs.Cloudiness.png")

# %% [markdown]
# ###### City cloudiness is spread all over the latitude

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Creating the Latitude vs. Wind Speed Scatter Plot

plt.title("City Latitude vs. Wind Speed(10/27/2020)", fontsize = 20)
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Wind Speed (mph)", fontsize = 12)

plt.scatter(Weather_pd["Lat"],Weather_pd["Wind Speed"], facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

plt.savefig("../Images/City Latitude vs.Wind Speed.png")

# %% [markdown]
# ###### As the laitude increases, Wind speed is spreading at same mph

# %% [markdown]
# #  Linear Regression

# %%
#Creating DataFrame for Northern Henisphere and Southern Hemisphere
southern_hemisphere = Weather_pd.loc[Weather_pd["Lat"]<0]
northern_hemisphere = Weather_pd.loc[Weather_pd["Lat"]>=0]

# %% [markdown]
# ##  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.title("Max Temp vs Latitude Linear Regression(Northern Hemisphere)", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (10,20), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Max Temp", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

plt.savefig("../Images/Temperatues at Latitude Positions(Northern Hemisphere.png")

# %% [markdown]
# ###### The plot shows negative correlation between Max Temp and Latitude in Northern Hemisphere

# %% [markdown]
# ##  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.title("Max Temp vs Latitude Linear Regression(Southern Hemisphere)", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (-20,5), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Max Temp", fontsize = 12)
plt.xlim = (0, -60)
plt.ylim = (40, 100)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

plt.savefig("../Images/Temperatues at Latitude Positions(Southern Hemisphere.png")

# %% [markdown]
# ###### The plot shows positive correlation between Max Temp and Latitude in Southern Hemisphere

# %% [markdown]
# ## Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.title("Northern Hemisphere - Humidity (%) vs. Latitude", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (50,20), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Humidity (%)", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

plt.savefig("../Images/Northern Hemisphere - Humidity (%) vs. Latitude.png")

# %% [markdown]
# ##### The plot shows moderate positive correlation between Humidity(%) and Latitude in Northern Hemisphere

# %% [markdown]
# ##  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.title("Southern Hemisphere - Humidity (%) vs. Latitude", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (-20,20), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Humidity (%)", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

plt.savefig("../Images/Southern Hemisphere - Humidity (%) vs. Latitude.png")

# %% [markdown]
# ##### The plot shows moderate positive correlation between Humidity(%) and Latitude in Southern Hemisphere

# %% [markdown]
# ## Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (10,20), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Cloudiness (%)", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

plt.savefig("../Images/Northern Hemisphere - Cloudiness (%) vs. Latitude.png")

# %% [markdown]
# ##### The plot shows moderate positive correlation between Cloudiness(%) and Latitude in Northern Hemisphere

# %% [markdown]
# ## Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (-50,80), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Cloudiness (%)", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

plt.savefig("../Images/Southern Hemisphere - Cloudiness (%) vs. Latitude.png")

# %% [markdown]
# ##### The plot shows positive correlation between Humidity(%) and Latitude in Southern Hemisphere

# %% [markdown]
# ## Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.title("Northern Hemisphere - Wind Speed(mph) vs. Latitude", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (60,10), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Wind Speed", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

plt.savefig("../Images/Northern Hemisphere - Wind Speed(mph) vs. Latitude.png")

# %% [markdown]
# ##### The plot shows moderate positive correlation between Wind Speed(mph) and Latitude in Northern Hemisphere

# %% [markdown]
# ## Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.title("Southern Hemisphere - Wind Speed(mph) vs. Latitude", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (-50,8), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Wind Speed(mph)", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

plt.savefig("../Images/Southern Hemisphere - Wind Speed(mph) vs. Latitude.png")

# %% [markdown]
# ##### The plot shows negative correlation between Wind Speed(mph) and Latitude in Southern Hemisphere

# %% [markdown]
# ##### Observations

# %% [markdown]
# ##### 1.Maximum temperature and Latitude work differently in Northern Hemishpere amd Southern Hemisphere. In Northern Hemishpere, max temperature and latitude are negatively correlated, which means that if the latitude increase max temperature decreases. Whereas in southern hemisphere its vice versa
#
# ##### 2.Cloudiness (%) and Latitude work similarly in both Northern Hemishpere amd Southern Hemisphere. The relation between cloudiness and latitude is moderately positively correlated in both hemispheres, which means as the latitude increases, the cloudiness also increases.
#
# ##### 3.For all the cities analyzed in the scatter plot, the cloudiness seem to be spead around all the latitude.
