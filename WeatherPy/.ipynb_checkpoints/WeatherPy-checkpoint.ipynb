# %%
#Dependencies and Setup
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
from scipy.stats import linregress
import scipy.stats as st

# %%
# Import API key
from config import weather_api_key

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\gagans\desktop\bootcamp\bootcamp\lib\site-packages (0.0.5)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: kdtree>=0.12 in c:\users\gagans\desktop\bootcamp\bootcamp\lib\site-packages (from citipy) (0.16)
# WARNING: You are using pip version 20.1.1; however, version 20.2.4 is available.
# You should consider upgrading via the 'c:\users\gagans\desktop\bootcamp\bootcamp\scripts\python.exe -m pip install --upgrade pip' command.

# %%
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
# Output File (CSV)
Output_data_file = "output_data/cities.csv"

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# # Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 625

# %% [markdown]
# #  Perform API Calls
#
# #### Perform a weather check on each city using a series of successive API calls.
# #### Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print("Beginning Data Retrieval")
print("-------------------------------")

#Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

#Build query url
endpoint = f"{url}appid={weather_api_key}&units={units}&q="

#Creating the response and store in json
#response = requests.get(url).json()

#Set empty list to hold each city's characteristics
city_name_list = []
cloudiness_list = []
country_list = []
data_list = []
humidity_list = []
lat_list = []
lon_list = []
temp_max_list = []
wind_speed_list = []
index_counter = 0
set_counter = 1


#Try to get the city data that is available in the OpenWeather API
for index, city in enumerate (cities, start = 1):
    try:
        response = requests.get(endpoint + city).json()
        city_name_list.append(response["name"])
        cloudiness_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        data_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lat_list.append(response["coord"]["lat"])
        lon_list.append(response["coord"]["lon"])
        temp_max_list.append(response["main"]["temp_max"])
        wind_speed_list.append(response["wind"]["speed"])

        
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
        
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record{index_counter} of set{set_counter}: {city}")
           
        
    except KeyError:
            print("City not found. Skipping...")
            
print("-----------------------------")
print("Data Retrival Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record1 of set1: babu
# Processing Record2 of set1: victoria
# City not found. Skipping...
# Processing Record3 of set1: vestmannaeyjar
# Processing Record4 of set1: grand-santi
# Processing Record5 of set1: umm kaddadah
# City not found. Skipping...
# Processing Record6 of set1: nishihara
# Processing Record7 of set1: biltine
# Processing Record8 of set1: caravelas
# Processing Record9 of set1: dikson
# Processing Record10 of set1: salalah
# Processing Record11 of set1: kapaa
# Processing Record12 of set1: ushuaia
# Processing Record13 of set1: upernavik
# Processing Record14 of set1: narsaq
# Processing Record15 of set1: margate
# Processing Record16 of set1: atar
# Processing Record17 of set1: henties bay
# Processing Record18 of set1: mataura
# Processing Record19 of set1: quarteira
# Processing Record20 of set1: isangel
# Processing Record21 of set1: estancia
# Processing Record22 of set1: buraydah
# City not found. Skipping...
# Processing Record23 of set1: rikitea
# City not found. Skipping...
# Processing Record24 of set1: hermanus
# Processing Record25 of set1: carnarvon
# Processing Record26 of set1: cape town
# Processing Record27 of set1: hithadhoo
# Processing Record28 of set1: port alfred
# City not found. Skipping...
# Processing Record29 of set1: hurghada
# Processing Record30 of set1: nantucket
# Processing Record31 of set1: hilo
# Processing Record32 of set1: pangnirtung
# Processing Record33 of set1: mossendjo
# Processing Record34 of set1: qaanaaq
# Processing Record35 of set1: busselton
# Processing Record36 of set1: jalu
# Processing Record37 of set1: saint-philippe
# Processing Record38 of set1: cidreira
# Processing Record39 of set1: sao filipe
# Processing Record40 of set1: rocha
# Processing Record41 of set1: castro
# Processing Record42 of set1: vostok
# Processing Record43 of set1: southbridge
# Processing Record44 of set1: broome
# Processing Record45 of set1: husavik
# Processing Record46 of set1: tasiilaq
# Processing Record47 of set1: butaritari
# Processing Record48 of set1: prince albert
# Processing Record49 of set1: arraial do cabo
# Processing Record50 of set1: samarai
# Processing Record0 of set2: albany
# Processing Record1 of set2: nanakuli
# Processing Record2 of set2: upington
# Processing Record3 of set2: lorengau
# Processing Record4 of set2: atuona
# Processing Record5 of set2: sitka
# Processing Record6 of set2: fairbanks
# Processing Record7 of set2: batticaloa
# Processing Record8 of set2: bengkulu
# Processing Record9 of set2: bonaventure
# Processing Record10 of set2: vaini
# City not found. Skipping...
# Processing Record11 of set2: mount gambier
# Processing Record12 of set2: jamestown
# Processing Record13 of set2: lengshuitan
# Processing Record14 of set2: tuktoyaktuk
# City not found. Skipping...
# Processing Record15 of set2: yumen
# City not found. Skipping...
# City not found. Skipping...
# Processing Record16 of set2: anadyr
# Processing Record17 of set2: pevek
# Processing Record18 of set2: east london
# Processing Record19 of set2: bowen
# Processing Record20 of set2: kaeo
# Processing Record21 of set2: kangaatsiaq
# Processing Record22 of set2: punta arenas
# Processing Record23 of set2: ambilobe
# Processing Record24 of set2: kulhudhuffushi
# Processing Record25 of set2: okato
# Processing Record26 of set2: barrow
# Processing Record27 of set2: kiunga
# Processing Record28 of set2: georgetown
# Processing Record29 of set2: bluff
# Processing Record30 of set2: jingdezhen
# Processing Record31 of set2: ancud
# Processing Record32 of set2: batagay
# Processing Record33 of set2: new norfolk
# Processing Record34 of set2: provideniya
# Processing Record35 of set2: palu
# City not found. Skipping...
# Processing Record36 of set2: sao cristovao
# Processing Record37 of set2: kerewan
# Processing Record38 of set2: ponta do sol
# Processing Record39 of set2: puerto ayora
# Processing Record40 of set2: roseburg
# Processing Record41 of set2: ust-kuyga
# Processing Record42 of set2: cherskiy
# Processing Record43 of set2: longyearbyen
# City not found. Skipping...
# Processing Record44 of set2: buin
# Processing Record45 of set2: acapulco
# City not found. Skipping...
# Processing Record46 of set2: aksarka
# Processing Record47 of set2: kirakira
# Processing Record48 of set2: golovino
# Processing Record49 of set2: soyo
# Processing Record50 of set2: cartagena
# Processing Record0 of set3: nouadhibou
# Processing Record1 of set3: saint george
# Processing Record2 of set3: montepuez
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record3 of set3: avarua
# Processing Record4 of set3: dhidhdhoo
# Processing Record5 of set3: linqiong
# City not found. Skipping...
# Processing Record6 of set3: mezen
# Processing Record7 of set3: labytnangi
# Processing Record8 of set3: eureka
# Processing Record9 of set3: jian
# Processing Record10 of set3: luderitz
# City not found. Skipping...
# Processing Record11 of set3: kupang
# Processing Record12 of set3: koutiala
# Processing Record13 of set3: ramshir
# City not found. Skipping...
# Processing Record14 of set3: hami
# Processing Record15 of set3: ilo
# Processing Record16 of set3: dongsheng
# Processing Record17 of set3: bredasdorp
# Processing Record18 of set3: huarmey
# Processing Record19 of set3: maryville
# Processing Record20 of set3: north battleford
# Processing Record21 of set3: severo-kurilsk
# Processing Record22 of set3: mar del plata
# Processing Record23 of set3: bandarbeyla
# Processing Record24 of set3: victor harbor
# Processing Record25 of set3: airai
# Processing Record26 of set3: san clemente
# Processing Record27 of set3: zhigansk
# Processing Record28 of set3: itaberai
# Processing Record29 of set3: hailar
# Processing Record30 of set3: cascais
# Processing Record31 of set3: saint-pierre
# Processing Record32 of set3: hofn
# Processing Record33 of set3: alappuzha
# Processing Record34 of set3: kobayashi
# Processing Record35 of set3: te anau
# Processing Record36 of set3: clyde river
# Processing Record37 of set3: payo
# Processing Record38 of set3: kikwit
# Processing Record39 of set3: codrington
# Processing Record40 of set3: magdalena
# Processing Record41 of set3: salekhard
# Processing Record42 of set3: moose factory
# City not found. Skipping...
# City not found. Skipping...
# Processing Record43 of set3: ahipara
# Processing Record44 of set3: penzance
# Processing Record45 of set3: adrar
# Processing Record46 of set3: tignere
# Processing Record47 of set3: christchurch
# Processing Record48 of set3: souillac
# Processing Record49 of set3: khatanga
# Processing Record50 of set3: ayan
# Processing Record0 of set4: ulladulla
# Processing Record1 of set4: boddam
# Processing Record2 of set4: hobart
# Processing Record3 of set4: yellowknife
# Processing Record4 of set4: tartus
# Processing Record5 of set4: iqaluit
# Processing Record6 of set4: jiujiang
# Processing Record7 of set4: lebanon
# Processing Record8 of set4: yulara
# Processing Record9 of set4: lima
# Processing Record10 of set4: goma
# Processing Record11 of set4: thompson
# City not found. Skipping...
# Processing Record12 of set4: kabelvag
# Processing Record13 of set4: chokurdakh
# Processing Record14 of set4: maragogi
# Processing Record15 of set4: buchmany
# Processing Record16 of set4: pisco
# Processing Record17 of set4: saskylakh
# Processing Record18 of set4: vung tau
# Processing Record19 of set4: nalut
# Processing Record20 of set4: naze
# Processing Record21 of set4: bethel
# Processing Record22 of set4: nisko
# Processing Record23 of set4: ndende
# Processing Record24 of set4: thinadhoo
# Processing Record25 of set4: napasar
# Processing Record26 of set4: fortuna
# Processing Record27 of set4: suhbaatar
# Processing Record28 of set4: tautira
# Processing Record29 of set4: meulaboh
# City not found. Skipping...
# City not found. Skipping...
# Processing Record30 of set4: hasaki
# Processing Record31 of set4: cayenne
# Processing Record32 of set4: torbay
# Processing Record33 of set4: port hawkesbury
# Processing Record34 of set4: lebu
# Processing Record35 of set4: port lincoln
# Processing Record36 of set4: mahebourg
# Processing Record37 of set4: ribeira grande
# Processing Record38 of set4: aripuana
# Processing Record39 of set4: vilshofen
# Processing Record40 of set4: corlu
# Processing Record41 of set4: ocos
# Processing Record42 of set4: los llanos de aridane
# Processing Record43 of set4: pierre
# Processing Record44 of set4: darab
# Processing Record45 of set4: carora
# Processing Record46 of set4: bom jesus da lapa
# Processing Record47 of set4: voka
# Processing Record48 of set4: rydultowy
# Processing Record49 of set4: edd
# Processing Record50 of set4: volodarskiy
# Processing Record0 of set5: flinders
# Processing Record1 of set5: tambacounda
# Processing Record2 of set5: nan
# Processing Record3 of set5: plettenberg bay
# Processing Record4 of set5: kieta
# Processing Record5 of set5: esperance
# Processing Record6 of set5: anshun
# Processing Record7 of set5: kaya
# Processing Record8 of set5: dali
# Processing Record9 of set5: kawalu
# Processing Record10 of set5: marsh harbour
# Processing Record11 of set5: cabo san lucas
# Processing Record12 of set5: lisakovsk
# Processing Record13 of set5: hecun
# Processing Record14 of set5: bilma
# Processing Record15 of set5: ler
# Processing Record16 of set5: port augusta
# Processing Record17 of set5: bubaque
# Processing Record18 of set5: yakeshi
# Processing Record19 of set5: kamen-rybolov
# Processing Record20 of set5: potoru
# Processing Record21 of set5: kampene
# Processing Record22 of set5: riyadh
# Processing Record23 of set5: avera
# Processing Record24 of set5: ponta delgada
# Processing Record25 of set5: beringovskiy
# Processing Record26 of set5: bathsheba
# City not found. Skipping...
# Processing Record27 of set5: umea
# City not found. Skipping...
# Processing Record28 of set5: talcahuano
# Processing Record29 of set5: kavieng
# Processing Record30 of set5: labuhan
# Processing Record31 of set5: guerrero negro
# Processing Record32 of set5: lata
# Processing Record33 of set5: bara
# Processing Record34 of set5: catuday
# Processing Record35 of set5: peniche
# Processing Record36 of set5: aklavik
# Processing Record37 of set5: chernyshevskiy
# Processing Record38 of set5: jiuquan
# Processing Record39 of set5: coquimbo
# Processing Record40 of set5: kathu
# Processing Record41 of set5: faanui
# Processing Record42 of set5: coron
# Processing Record43 of set5: tiksi
# Processing Record44 of set5: dale
# Processing Record45 of set5: macamic
# Processing Record46 of set5: padang
# Processing Record47 of set5: chuy
# Processing Record48 of set5: pangkalanbuun
# Processing Record49 of set5: bahia blanca
# Processing Record50 of set5: bridlington
# Processing Record0 of set6: broken hill
# Processing Record1 of set6: huanuco
# Processing Record2 of set6: guasdualito
# City not found. Skipping...
# Processing Record3 of set6: kaniama
# Processing Record4 of set6: grand gaube
# Processing Record5 of set6: yerbogachen
# Processing Record6 of set6: bonthe
# Processing Record7 of set6: harper
# Processing Record8 of set6: qui nhon
# Processing Record9 of set6: springbok
# Processing Record10 of set6: homer
# Processing Record11 of set6: xudat
# Processing Record12 of set6: kanniyakumari
# Processing Record13 of set6: milos
# Processing Record14 of set6: pilar
# Processing Record15 of set6: kemi
# City not found. Skipping...
# Processing Record16 of set6: nanortalik
# Processing Record17 of set6: erzin
# Processing Record18 of set6: belyy yar
# Processing Record19 of set6: denpasar
# Processing Record20 of set6: san patricio
# Processing Record21 of set6: dalby
# Processing Record22 of set6: karoi
# Processing Record23 of set6: yenagoa
# Processing Record24 of set6: limbang
# Processing Record25 of set6: constitucion
# Processing Record26 of set6: calbuco
# Processing Record27 of set6: oussouye
# Processing Record28 of set6: ati
# Processing Record29 of set6: kaitangata
# Processing Record30 of set6: veraval
# Processing Record31 of set6: palpa
# Processing Record32 of set6: port-cartier
# Processing Record33 of set6: alugan
# Processing Record34 of set6: cabadiangan
# Processing Record35 of set6: itoman
# Processing Record36 of set6: comodoro rivadavia
# Processing Record37 of set6: eyl
# Processing Record38 of set6: rongcheng
# Processing Record39 of set6: gazojak
# Processing Record40 of set6: mporokoso
# Processing Record41 of set6: kincardine
# Processing Record42 of set6: nome
# Processing Record43 of set6: haines junction
# Processing Record44 of set6: abu zabad
# Processing Record45 of set6: viedma
# Processing Record46 of set6: vestmanna
# Processing Record47 of set6: pringsewu
# Processing Record48 of set6: andenes
# Processing Record49 of set6: winneba
# Processing Record50 of set6: san carlos de bariloche
# Processing Record0 of set7: ashcroft
# Processing Record1 of set7: port elizabeth
# Processing Record2 of set7: kushima
# City not found. Skipping...
# Processing Record3 of set7: satipo
# Processing Record4 of set7: krasnovishersk
# Processing Record5 of set7: kruisfontein
# City not found. Skipping...
# Processing Record6 of set7: namatanai
# Processing Record7 of set7: quelimane
# Processing Record8 of set7: sfantu gheorghe
# Processing Record9 of set7: shenjiamen
# Processing Record10 of set7: laguna
# Processing Record11 of set7: tuatapere
# Processing Record12 of set7: ulaangom
# Processing Record13 of set7: bud
# Processing Record14 of set7: vitim
# City not found. Skipping...
# Processing Record15 of set7: korla
# Processing Record16 of set7: north bend
# Processing Record17 of set7: villa corzo
# Processing Record18 of set7: klaksvik
# Processing Record19 of set7: sakaiminato
# City not found. Skipping...
# Processing Record20 of set7: warrnambool
# Processing Record21 of set7: kodiak
# Processing Record22 of set7: svetlyy
# Processing Record23 of set7: beisfjord
# Processing Record24 of set7: gwadar
# Processing Record25 of set7: khash
# Processing Record26 of set7: santa cruz
# Processing Record27 of set7: tias
# Processing Record28 of set7: warwick
# Processing Record29 of set7: djambala
# Processing Record30 of set7: san quintin
# Processing Record31 of set7: manicaragua
# Processing Record32 of set7: slave lake
# Processing Record33 of set7: maymyo
# Processing Record34 of set7: nikko
# Processing Record35 of set7: ostrovnoy
# Processing Record36 of set7: pontianak
# Processing Record37 of set7: karasburg
# Processing Record38 of set7: changzhou
# Processing Record39 of set7: inuvik
# Processing Record40 of set7: lompoc
# Processing Record41 of set7: mayumba
# Processing Record42 of set7: burnie
# Processing Record43 of set7: kalvarija
# Processing Record44 of set7: aquiraz
# Processing Record45 of set7: muroto
# Processing Record46 of set7: deputatskiy
# Processing Record47 of set7: kwinana
# Processing Record48 of set7: bilibino
# Processing Record49 of set7: santa comba
# Processing Record50 of set7: norman wells
# Processing Record0 of set8: abu dhabi
# Processing Record1 of set8: baykit
# Processing Record2 of set8: zhanakorgan
# Processing Record3 of set8: puerto quijarro
# Processing Record4 of set8: mandera
# Processing Record5 of set8: graaff-reinet
# Processing Record6 of set8: belmonte
# Processing Record7 of set8: matagami
# Processing Record8 of set8: manati
# Processing Record9 of set8: dingle
# Processing Record10 of set8: belaya gora
# Processing Record11 of set8: imbituba
# Processing Record12 of set8: pueblo
# Processing Record13 of set8: katsuura
# Processing Record14 of set8: nelson bay
# Processing Record15 of set8: iberia
# Processing Record16 of set8: carballo
# Processing Record17 of set8: robertsport
# Processing Record18 of set8: mitsamiouli
# Processing Record19 of set8: axim
# Processing Record20 of set8: sainte-rose
# Processing Record21 of set8: kaili
# Processing Record22 of set8: praia
# Processing Record23 of set8: shingu
# City not found. Skipping...
# Processing Record24 of set8: bosaso
# Processing Record25 of set8: salo
# Processing Record26 of set8: lafiagi
# Processing Record27 of set8: necochea
# Processing Record28 of set8: touros
# Processing Record29 of set8: amahai
# City not found. Skipping...
# Processing Record30 of set8: tateyama
# Processing Record31 of set8: pochutla
# Processing Record32 of set8: sangar
# Processing Record33 of set8: binga
# Processing Record34 of set8: hengshui
# Processing Record35 of set8: kaduna
# City not found. Skipping...
# Processing Record36 of set8: sept-iles
# Processing Record37 of set8: busteni
# Processing Record38 of set8: saurimo
# Processing Record39 of set8: inirida
# Processing Record40 of set8: oswego
# Processing Record41 of set8: nikolskoye
# Processing Record42 of set8: itupiranga
# Processing Record43 of set8: vanimo
# Processing Record44 of set8: kibakwe
# Processing Record45 of set8: lavrentiya
# Processing Record46 of set8: ewa beach
# Processing Record47 of set8: chalus
# City not found. Skipping...
# Processing Record48 of set8: buala
# Processing Record49 of set8: sinnamary
# Processing Record50 of set8: san policarpo
# Processing Record0 of set9: nemuro
# Processing Record1 of set9: rorvik
# Processing Record2 of set9: port hardy
# Processing Record3 of set9: novobirilyussy
# Processing Record4 of set9: ilulissat
# Processing Record5 of set9: morfelden-walldorf
# Processing Record6 of set9: watertown
# Processing Record7 of set9: ulaanbaatar
# Processing Record8 of set9: yongan
# Processing Record9 of set9: kimbe
# Processing Record10 of set9: kenai
# Processing Record11 of set9: montrose
# Processing Record12 of set9: portales
# Processing Record13 of set9: chimore
# Processing Record14 of set9: garissa
# City not found. Skipping...
# Processing Record15 of set9: pundaguitan
# Processing Record16 of set9: gamboma
# Processing Record17 of set9: tacuati
# Processing Record18 of set9: monroe
# Processing Record19 of set9: verkhoyansk
# Processing Record20 of set9: makakilo city
# Processing Record21 of set9: yeppoon
# Processing Record22 of set9: ngunguru
# Processing Record23 of set9: seddon
# Processing Record24 of set9: port hedland
# Processing Record25 of set9: sorgues
# Processing Record26 of set9: dhone
# Processing Record27 of set9: namibe
# Processing Record28 of set9: vangaindrano
# Processing Record29 of set9: kismayo
# Processing Record30 of set9: pozo colorado
# Processing Record31 of set9: geraldton
# Processing Record32 of set9: savalou
# Processing Record33 of set9: desaguadero
# Processing Record34 of set9: mao
# City not found. Skipping...
# Processing Record35 of set9: lanivtsi
# Processing Record36 of set9: udachnyy
# Processing Record37 of set9: kitimat
# Processing Record38 of set9: tiznit
# Processing Record39 of set9: kirksville
# City not found. Skipping...
# Processing Record40 of set9: kitui
# Processing Record41 of set9: sao borja
# Processing Record42 of set9: richards bay
# Processing Record43 of set9: havre-saint-pierre
# Processing Record44 of set9: rio grande
# Processing Record45 of set9: byron bay
# Processing Record46 of set9: mokhsogollokh
# Processing Record47 of set9: mandalgovi
# Processing Record48 of set9: makurdi
# Processing Record49 of set9: zhezkazgan
# Processing Record50 of set9: talnakh
# Processing Record0 of set10: teguldet
# Processing Record1 of set10: kununurra
# Processing Record2 of set10: benguela
# Processing Record3 of set10: la palma
# Processing Record4 of set10: high level
# Processing Record5 of set10: honiara
# Processing Record6 of set10: alofi
# Processing Record7 of set10: clarence town
# Processing Record8 of set10: puno
# Processing Record9 of set10: gamba
# Processing Record10 of set10: hitoyoshi
# Processing Record11 of set10: seoul
# Processing Record12 of set10: kvareli
# Processing Record13 of set10: farafangana
# City not found. Skipping...
# Processing Record14 of set10: nyeri
# Processing Record15 of set10: komsomolskiy
# Processing Record16 of set10: ratnagiri
# Processing Record17 of set10: beloha
# Processing Record18 of set10: poum
# Processing Record19 of set10: praia da vitoria
# Processing Record20 of set10: whitehorse
# Processing Record21 of set10: tra vinh
# Processing Record22 of set10: ust-nera
# Processing Record23 of set10: dores do indaia
# Processing Record24 of set10: grenfell
# Processing Record25 of set10: catamarca
# City not found. Skipping...
# Processing Record26 of set10: basoko
# Processing Record27 of set10: juan aldama
# Processing Record28 of set10: coaticook
# Processing Record29 of set10: atherton
# Processing Record30 of set10: arlit
# Processing Record31 of set10: mackay
# Processing Record32 of set10: emerald
# Processing Record33 of set10: mocuba
# Processing Record34 of set10: andreyevo
# Processing Record35 of set10: prince rupert
# Processing Record36 of set10: nichinan
# Processing Record37 of set10: inhambane
# Processing Record38 of set10: huatulco
# Processing Record39 of set10: kasempa
# Processing Record40 of set10: santa fe
# Processing Record41 of set10: cartagena del chaira
# Processing Record42 of set10: otjiwarongo
# Processing Record43 of set10: zapolyarnyy
# Processing Record44 of set10: alekseyevsk
# Processing Record45 of set10: saldanha
# Processing Record46 of set10: naryan-mar
# Processing Record47 of set10: aksu
# Processing Record48 of set10: okhotsk
# Processing Record49 of set10: ejea de los caballeros
# Processing Record50 of set10: paro
# City not found. Skipping...
# Processing Record0 of set11: glendive
# Processing Record1 of set11: wad rawah
# Processing Record2 of set11: kitob
# Processing Record3 of set11: manadhoo
# Processing Record4 of set11: koslan
# Processing Record5 of set11: presidente epitacio
# Processing Record6 of set11: sioux lookout
# Processing Record7 of set11: ola
# Processing Record8 of set11: pak phanang
# Processing Record9 of set11: portland
# Processing Record10 of set11: verkhovazhye
# Processing Record11 of set11: gorontalo
# Processing Record12 of set11: saint-augustin
# Processing Record13 of set11: coxim
# Processing Record14 of set11: paka
# Processing Record15 of set11: dangriga
# Processing Record16 of set11: hambantota
# Processing Record17 of set11: loreto
# Processing Record18 of set11: lagoa
# Processing Record19 of set11: bull savanna
# Processing Record20 of set11: palmer
# Processing Record21 of set11: ingham
# Processing Record22 of set11: ibra
# Processing Record23 of set11: tornio
# Processing Record24 of set11: brownwood
# Processing Record25 of set11: mayor pablo lagerenza
# Processing Record26 of set11: siteki
# Processing Record27 of set11: tshikapa
# Processing Record28 of set11: sinnai
# Processing Record29 of set11: japura
# City not found. Skipping...
# Processing Record30 of set11: grindavik
# City not found. Skipping...
# Processing Record31 of set11: dilla
# City not found. Skipping...
# Processing Record32 of set11: hue
# Processing Record33 of set11: sungaipenuh
# Processing Record34 of set11: koppang
# Processing Record35 of set11: china
# Processing Record36 of set11: jacareacanga
# Processing Record37 of set11: xinyu
# Processing Record38 of set11: alexandria
# Processing Record39 of set11: ukiah
# Processing Record40 of set11: sulangan
# Processing Record41 of set11: jijiga
# Processing Record42 of set11: pacific grove
# Processing Record43 of set11: marawi
# Processing Record44 of set11: belle glade
# Processing Record45 of set11: guayaramerin
# Processing Record46 of set11: samarkand
# Processing Record47 of set11: nokaneng
# Processing Record48 of set11: kokopo
# Processing Record49 of set11: sorong
# Processing Record50 of set11: maniitsoq
# Processing Record0 of set12: noumea
# Processing Record1 of set12: opuwo
# City not found. Skipping...
# Processing Record2 of set12: san cristobal
# Processing Record3 of set12: muros
# City not found. Skipping...
# Processing Record4 of set12: bambous virieux
# Processing Record5 of set12: rio gallegos
# Processing Record6 of set12: kiama
# Processing Record7 of set12: agapovka
# Processing Record8 of set12: vila franca do campo
# Processing Record9 of set12: porto velho
# City not found. Skipping...
# Processing Record10 of set12: show low
# Processing Record11 of set12: la roda
# Processing Record12 of set12: saint-leu
# Processing Record13 of set12: myrtle beach
# Processing Record14 of set12: solnechnyy
# Processing Record15 of set12: trairi
# Processing Record16 of set12: colwyn bay
# Processing Record17 of set12: sao joao da barra
# -----------------------------
# Data Retrival Complete
# -----------------------------

# %% [markdown]
# # Convert Raw Data to DataFrame
#
# #### Export the city data into a .csv.
# #### Display the DataFrame

# %%
#Creating a dataframe with information received
Weather_pd = pd.DataFrame({
                        "City" : city_name_list, 
                        "Cloudiness" : cloudiness_list,
                        "Country" : country_list,
                        "Date" : data_list,
                        "Humidity" : humidity_list,
                        "Lat" : lat_list,
                        "Lon" : lon_list,
                        "Max Temp" : temp_max_list,
                        "Wind Speed" : wind_speed_list 
    
})

# %%
#Counting the data
Weather_pd.count()
# Out:
# City          578
# Cloudiness    578
# Country       578
# Date          578
# Humidity      578
# Lat           578
# Lon           578
# Max Temp      578
# Wind Speed    578
# dtype: int64

# %%
#Displaying the DataFrame
Weather_pd.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lon  \
# 0            Babu          99      CN  1603936256        85  24.42  111.52
# 1       Hong Kong          94      HK  1603936157        65  22.29  114.16
# 2  Vestmannaeyjar          49      IS  1603936257        79  63.44  -20.27
# 3     Grand-Santi          64      GF  1603936257        69   4.25  -54.38
# 4    Umm Kaddadah           4      SD  1603936257        23  13.60   26.69
#
#    Max Temp  Wind Speed
# 0     64.02        6.29
# 1     77.00        5.99
# 2     45.88       44.27
# 3     79.95        4.00
# 4     81.16       18.61

# %%
#Export city data into a .CSV file
Weather_pd.to_csv("Output_data_file", index = False)

# %% [markdown]
# # Plotting the Data
#
# #### Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# #### Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Creating the Latitude vs. Temperature Scatter Plot

#Setting the plot title, xlabel, ylabel and grid
plt.title("City Latitude vs.Max Temperature(10/27/2020)", fontsize = 20)
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Max Temperature (F)", fontsize = 12)

plt.scatter(Weather_pd["Lat"],Weather_pd["Max Temp"], facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)

#Saving the plot fig as .png
plt.savefig("../Images/City Latitude vs Max Temperature.png")
plt.show()

# %% [markdown]
# ###### As the Latitude is increasing the temperature drops

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Creating the Latitude vs. Humidity Scatter Plot

#Setting the plot title, xlabel, ylabel and grid
plt.title("City Latitude vs. Humidity(10/27/2020)", fontsize = 20)
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Humidity (%)", fontsize = 12)

plt.scatter(Weather_pd["Lat"],Weather_pd["Humidity"], facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)

#Saving the plot fig as .png
plt.savefig("../Images/City Latitude vs Humidity.png")

plt.show()

# %% [markdown]
# ###### As Latitude increases Humidity also increases

# %% [markdown]
# ##  Latitude vs. Cloudiness Plot

# %%
#Creating the Latitude vs. Cloudiness Scatter Plot

#Setting the plot title, xlabel, ylabel and grid
plt.title("City Latitude vs. Cloudiness(10/27/2020)", fontsize = 20)
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Cloudiness (%)", fontsize = 12)

plt.scatter(Weather_pd["Lat"],Weather_pd["Cloudiness"], facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)


#Saving the plot fig as .png
plt.savefig("../Images/City Latitude vs Cloudiness.png")

plt.show()

# %% [markdown]
# ###### City cloudiness is spread all over the latitude

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Creating the Latitude vs. Wind Speed Scatter Plot

#Setting the plot title, xlabel, ylabel and grid
plt.title("City Latitude vs. Wind Speed(10/27/2020)", fontsize = 20)
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Wind Speed (mph)", fontsize = 12)

plt.scatter(Weather_pd["Lat"],Weather_pd["Wind Speed"], facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)

#Saving the plot fig as .png
plt.savefig("../Images/City Latitude vs Wind Speed.png")

plt.show()

# %% [markdown]
# ###### As the laitude increases, Wind speed is spreading at same mph

# %% [markdown]
# #  Linear Regression

# %%
#Creating DataFrame for Northern Henisphere and Southern Hemisphere
southern_hemisphere = Weather_pd.loc[Weather_pd["Lat"]<0]
northern_hemisphere = Weather_pd.loc[Weather_pd["Lat"]>=0]

# %% [markdown]
# ##  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Creating linear regression and scatter plots
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Max Temp vs Latitude Linear Regression(Northern Hemisphere)", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (10,20), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Max Temp", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)


#Saving the plot fig as .png
plt.savefig("../Images/Temperatues at Latitude Positions(Northern Hemisphere.png")

plt.show()

# %% [markdown]
# ###### The plot shows negative correlation between Max Temp and Latitude in Northern Hemisphere

# %% [markdown]
# ##  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Max Temp vs Latitude Linear Regression(Southern Hemisphere)", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (-20,5), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Max Temp", fontsize = 12)
plt.xlim = (0, -60)
plt.ylim = (40, 100)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)

#Saving the plot fig as .png
plt.savefig("../Images/Temperatues at Latitude Positions(Southern Hemisphere.png")

plt.show()

# %% [markdown]
# ###### The plot shows positive correlation between Max Temp and Latitude in Southern Hemisphere

# %% [markdown]
# ## Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (50,20), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Humidity (%)", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)


#Saving the plot fig as .png
plt.savefig("../Images/Northern Hemisphere - Humidity (%) vs. Latitude.png")

plt.show()

# %% [markdown]
# ##### The plot shows moderate positive correlation between Humidity(%) and Latitude in Northern Hemisphere

# %% [markdown]
# ##  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (-20,20), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Humidity (%)", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)


#Saving the plot fig as .png
plt.savefig("../Images/Southern Hemisphere - Humidity (%) vs. Latitude.png")

plt.show()

# %% [markdown]
# ##### The plot shows moderate positive correlation between Humidity(%) and Latitude in Southern Hemisphere

# %% [markdown]
# ## Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (10,20), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Cloudiness (%)", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)


#Saving the plot fig as .png
plt.savefig("../Images/Northern Hemisphere - Cloudiness (%) vs. Latitude.png")

plt.show()

# %% [markdown]
# ##### The plot shows moderate positive correlation between Cloudiness(%) and Latitude in Northern Hemisphere

# %% [markdown]
# ## Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (-50,80), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Cloudiness (%)", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)

#Saving the plot fig as .png
plt.savefig("../Images/Southern Hemisphere - Cloudiness (%) vs. Latitude.png")

plt.show()

# %% [markdown]
# ##### The plot shows positive correlation between Cloudiness(%) and Latitude in Southern Hemisphere

# %% [markdown]
# ## Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Northern Hemisphere - Wind Speed(mph) vs. Latitude", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (60,10), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Wind Speed", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)

#Saving the plot fig as .png
plt.savefig("../Images/Northern Hemisphere - Wind Speed(mph) vs. Latitude.png")

plt.show()

# %% [markdown]
# ##### The plot shows moderate positive correlation between Wind Speed(mph) and Latitude in Northern Hemisphere

# %% [markdown]
# ## Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Southern Hemisphere - Wind Speed(mph) vs. Latitude", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (-50,8), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Wind Speed(mph)", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)

#Saving the plot fig as .png
plt.savefig("../Images/Southern Hemisphere - Wind Speed(mph) vs. Latitude.png")

plt.show()

# %% [markdown]
# ##### The plot shows negative correlation between Wind Speed(mph) and Latitude in Southern Hemisphere

# %% [markdown]
# ### Observations

# %% [markdown]
# ##### 1.Maximum temperature and Latitude work differently in Northern Hemishpere amd Southern Hemisphere. In Northern Hemishpere, max temperature and latitude are negatively correlated, which means that if the latitude increase max temperature decreases. Whereas in southern hemisphere its vice versa
#
# ##### 2.Cloudiness (%) and Latitude work similarly in both Northern Hemishpere amd Southern Hemisphere. The relation between cloudiness and latitude is moderately positively correlated in both hemispheres, which means as the latitude increases, the cloudiness also increases.
#
# ##### 3.For all the cities analyzed in the scatter plot, the cloudiness seem to be spead around all the latitudes.
