# %%
#Dependencies and Setup
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
from scipy.stats import linregress
import scipy.stats as st

# %%
# Import API key
from config import weather_api_key

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\gagans\desktop\bootcamp\bootcamp\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\gagans\desktop\bootcamp\bootcamp\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.1.1; however, version 20.2.4 is available.
# You should consider upgrading via the 'c:\users\gagans\desktop\bootcamp\bootcamp\scripts\python.exe -m pip install --upgrade pip' command.

# %%
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
# Output File (CSV)
Output_data_file = "output_data/cities.csv"

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# # Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 629

# %% [markdown]
# #  Perform API Calls
#
# #### Perform a weather check on each city using a series of successive API calls.
# #### Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print("Beginning Data Retrieval")
print("-------------------------------")

#Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

#Build query url
endpoint = f"{url}appid={weather_api_key}&units={units}&q="

#Creating the response and store in json
#response = requests.get(url).json()

#Set empty list to hold each city's characteristics
city_name_list = []
cloudiness_list = []
country_list = []
data_list = []
humidity_list = []
lat_list = []
lon_list = []
temp_max_list = []
wind_speed_list = []
index_counter = 0
set_counter = 1


#Try to get the city data that is available in the OpenWeather API
for index, city in enumerate (cities, start = 1):
    try:
        response = requests.get(endpoint + city).json()
        city_name_list.append(response["name"])
        cloudiness_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        data_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lat_list.append(response["coord"]["lat"])
        lon_list.append(response["coord"]["lon"])
        temp_max_list.append(response["main"]["temp_max"])
        wind_speed_list.append(response["wind"]["speed"])

        
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
        
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record{index_counter} of set{set_counter}: {city}")
           
        
    except KeyError:
            print("City not found. Skipping...")
            
print("-----------------------------")
print("Data Retrival Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record1 of set1: avarua
# Processing Record2 of set1: butaritari
# Processing Record3 of set1: cabo san lucas
# Processing Record4 of set1: mataura
# Processing Record5 of set1: airai
# Processing Record6 of set1: qaanaaq
# Processing Record7 of set1: sitka
# Processing Record8 of set1: banda aceh
# Processing Record9 of set1: yellowknife
# Processing Record10 of set1: kidodi
# City not found. Skipping...
# Processing Record11 of set1: saint-philippe
# City not found. Skipping...
# Processing Record12 of set1: diu
# City not found. Skipping...
# Processing Record13 of set1: taguatinga
# Processing Record14 of set1: roura
# Processing Record15 of set1: asfi
# Processing Record16 of set1: ushuaia
# Processing Record17 of set1: tres arroyos
# Processing Record18 of set1: punta arenas
# Processing Record19 of set1: lagoa
# Processing Record20 of set1: mount gambier
# Processing Record21 of set1: rikitea
# Processing Record22 of set1: kavieng
# Processing Record23 of set1: atuona
# Processing Record24 of set1: cape town
# Processing Record25 of set1: kapaa
# Processing Record26 of set1: ilulissat
# Processing Record27 of set1: luderitz
# Processing Record28 of set1: piraju
# Processing Record29 of set1: tutoia
# Processing Record30 of set1: sibolga
# Processing Record31 of set1: vila velha
# Processing Record32 of set1: chuy
# Processing Record33 of set1: quelimane
# Processing Record34 of set1: port elizabeth
# Processing Record35 of set1: busselton
# Processing Record36 of set1: hithadhoo
# Processing Record37 of set1: raudeberg
# Processing Record38 of set1: mar del plata
# Processing Record39 of set1: maltahohe
# Processing Record40 of set1: husavik
# Processing Record41 of set1: nanortalik
# City not found. Skipping...
# Processing Record42 of set1: vaini
# Processing Record43 of set1: east london
# Processing Record44 of set1: camana
# Processing Record45 of set1: saint-augustin
# Processing Record46 of set1: meulaboh
# Processing Record47 of set1: hobart
# Processing Record48 of set1: ust-maya
# Processing Record49 of set1: maceio
# Processing Record50 of set1: new norfolk
# Processing Record0 of set2: dalvik
# Processing Record1 of set2: murgab
# Processing Record2 of set2: mwingi
# Processing Record3 of set2: mao
# Processing Record4 of set2: pacific grove
# Processing Record5 of set2: la ronge
# Processing Record6 of set2: necochea
# Processing Record7 of set2: kisaran
# Processing Record8 of set2: vao
# Processing Record9 of set2: jamestown
# City not found. Skipping...
# Processing Record10 of set2: werl
# Processing Record11 of set2: phalodi
# Processing Record12 of set2: tasiilaq
# Processing Record13 of set2: asau
# Processing Record14 of set2: umm kaddadah
# Processing Record15 of set2: albany
# City not found. Skipping...
# Processing Record16 of set2: mackay
# Processing Record17 of set2: paita
# Processing Record18 of set2: high river
# Processing Record19 of set2: almeirim
# Processing Record20 of set2: barrow
# Processing Record21 of set2: vestmanna
# Processing Record22 of set2: komsomolskiy
# Processing Record23 of set2: bluff
# Processing Record24 of set2: ancud
# Processing Record25 of set2: zemio
# Processing Record26 of set2: winder
# Processing Record27 of set2: sola
# Processing Record28 of set2: bredasdorp
# Processing Record29 of set2: esperance
# Processing Record30 of set2: usinsk
# Processing Record31 of set2: saskylakh
# Processing Record32 of set2: quatre cocos
# Processing Record33 of set2: felanitx
# Processing Record34 of set2: upernavik
# City not found. Skipping...
# Processing Record35 of set2: victoria
# Processing Record36 of set2: puerto ayora
# City not found. Skipping...
# Processing Record37 of set2: odesskoye
# Processing Record38 of set2: provideniya
# Processing Record39 of set2: hilo
# City not found. Skipping...
# Processing Record40 of set2: salalah
# Processing Record41 of set2: saldanha
# Processing Record42 of set2: rio grande
# Processing Record43 of set2: severo-kurilsk
# Processing Record44 of set2: tautira
# Processing Record45 of set2: souillac
# Processing Record46 of set2: pisco
# Processing Record47 of set2: novikovo
# Processing Record48 of set2: grindavik
# Processing Record49 of set2: batagay-alyta
# Processing Record50 of set2: tocopilla
# Processing Record0 of set3: contamana
# Processing Record1 of set3: gizo
# Processing Record2 of set3: zyryanka
# Processing Record3 of set3: bethel
# Processing Record4 of set3: dubbo
# Processing Record5 of set3: san patricio
# Processing Record6 of set3: ribeira grande
# Processing Record7 of set3: nikel
# Processing Record8 of set3: dikson
# Processing Record9 of set3: leningradskiy
# City not found. Skipping...
# Processing Record10 of set3: remanso
# Processing Record11 of set3: port alfred
# Processing Record12 of set3: lorengau
# Processing Record13 of set3: pindwara
# Processing Record14 of set3: padang
# Processing Record15 of set3: inongo
# Processing Record16 of set3: kaeo
# Processing Record17 of set3: georgetown
# Processing Record18 of set3: carnarvon
# Processing Record19 of set3: saint anthony
# Processing Record20 of set3: bestobe
# Processing Record21 of set3: mitu
# Processing Record22 of set3: aksu
# Processing Record23 of set3: labuhan
# Processing Record24 of set3: petropavlovsk-kamchatskiy
# City not found. Skipping...
# Processing Record25 of set3: college
# Processing Record26 of set3: nabire
# Processing Record27 of set3: torbay
# Processing Record28 of set3: vila
# Processing Record29 of set3: burnie
# Processing Record30 of set3: arraial do cabo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record31 of set3: lebu
# Processing Record32 of set3: chinsali
# Processing Record33 of set3: gualaquiza
# Processing Record34 of set3: nikolskoye
# Processing Record35 of set3: atbasar
# Processing Record36 of set3: shakiso
# Processing Record37 of set3: tucuma
# Processing Record38 of set3: kodiak
# Processing Record39 of set3: hofn
# Processing Record40 of set3: gewane
# Processing Record41 of set3: elko
# Processing Record42 of set3: laguna
# Processing Record43 of set3: xining
# Processing Record44 of set3: salta
# Processing Record45 of set3: thompson
# Processing Record46 of set3: sungaipenuh
# Processing Record47 of set3: algiers
# Processing Record48 of set3: broome
# Processing Record49 of set3: isangel
# Processing Record50 of set3: hamilton
# Processing Record0 of set4: asgabat
# Processing Record1 of set4: cidreira
# Processing Record2 of set4: touros
# Processing Record3 of set4: kita
# Processing Record4 of set4: kodinar
# Processing Record5 of set4: nuuk
# Processing Record6 of set4: pierre
# Processing Record7 of set4: kochki
# Processing Record8 of set4: ponta do sol
# Processing Record9 of set4: masuguru
# Processing Record10 of set4: frutal
# Processing Record11 of set4: koumac
# Processing Record12 of set4: westport
# Processing Record13 of set4: beni suef
# Processing Record14 of set4: turukhansk
# Processing Record15 of set4: hay river
# Processing Record16 of set4: lazaro cardenas
# Processing Record17 of set4: zenzeli
# Processing Record18 of set4: san cristobal
# Processing Record19 of set4: porto novo
# Processing Record20 of set4: coruripe
# Processing Record21 of set4: constitucion
# Processing Record22 of set4: chokurdakh
# Processing Record23 of set4: tazovskiy
# Processing Record24 of set4: sioux lookout
# Processing Record25 of set4: rio verde de mato grosso
# City not found. Skipping...
# Processing Record26 of set4: meadow lake
# Processing Record27 of set4: mahebourg
# Processing Record28 of set4: ouango
# Processing Record29 of set4: vardo
# Processing Record30 of set4: genhe
# Processing Record31 of set4: devils lake
# Processing Record32 of set4: ahipara
# Processing Record33 of set4: ostrovnoy
# Processing Record34 of set4: renigunta
# Processing Record35 of set4: saint george
# Processing Record36 of set4: pevek
# Processing Record37 of set4: hermanus
# Processing Record38 of set4: shimanovsk
# Processing Record39 of set4: caravelas
# Processing Record40 of set4: kibaya
# Processing Record41 of set4: akdepe
# Processing Record42 of set4: waingapu
# Processing Record43 of set4: myitkyina
# Processing Record44 of set4: alofi
# City not found. Skipping...
# Processing Record45 of set4: olafsvik
# Processing Record46 of set4: muros
# City not found. Skipping...
# Processing Record47 of set4: cockburn town
# Processing Record48 of set4: juarez
# Processing Record49 of set4: lasa
# Processing Record50 of set4: aksum
# Processing Record0 of set5: cayenne
# Processing Record1 of set5: laela
# Processing Record2 of set5: alibag
# City not found. Skipping...
# Processing Record3 of set5: namibe
# Processing Record4 of set5: cooma
# Processing Record5 of set5: madera
# Processing Record6 of set5: nome
# Processing Record7 of set5: dingle
# Processing Record8 of set5: geraldton
# Processing Record9 of set5: lompoc
# Processing Record10 of set5: yuxia
# Processing Record11 of set5: tuktoyaktuk
# Processing Record12 of set5: rosetown
# City not found. Skipping...
# Processing Record13 of set5: culaman
# Processing Record14 of set5: gidam
# Processing Record15 of set5: muzhi
# City not found. Skipping...
# Processing Record16 of set5: sistranda
# Processing Record17 of set5: longyearbyen
# Processing Record18 of set5: kenai
# Processing Record19 of set5: san jose
# Processing Record20 of set5: road town
# Processing Record21 of set5: athabasca
# Processing Record22 of set5: katherine
# Processing Record23 of set5: yerbogachen
# Processing Record24 of set5: hobyo
# Processing Record25 of set5: forotic
# City not found. Skipping...
# Processing Record26 of set5: talnakh
# Processing Record27 of set5: palmer
# Processing Record28 of set5: bengkulu
# Processing Record29 of set5: ulaangom
# Processing Record30 of set5: lillooet
# City not found. Skipping...
# Processing Record31 of set5: beringovskiy
# Processing Record32 of set5: tilichiki
# City not found. Skipping...
# Processing Record33 of set5: tuatapere
# Processing Record34 of set5: vanimo
# Processing Record35 of set5: visby
# Processing Record36 of set5: mumford
# Processing Record37 of set5: khatanga
# Processing Record38 of set5: katsuura
# Processing Record39 of set5: shubarshi
# Processing Record40 of set5: honningsvag
# Processing Record41 of set5: castro
# Processing Record42 of set5: beyla
# Processing Record43 of set5: ballina
# Processing Record44 of set5: deputatskiy
# Processing Record45 of set5: fairbanks
# Processing Record46 of set5: vila franca do campo
# Processing Record47 of set5: sao joao da barra
# Processing Record48 of set5: ketchikan
# Processing Record49 of set5: nouadhibou
# Processing Record50 of set5: stepnyak
# Processing Record0 of set6: eyl
# Processing Record1 of set6: santa ana
# Processing Record2 of set6: amod
# Processing Record3 of set6: sao filipe
# Processing Record4 of set6: fenoarivo
# Processing Record5 of set6: polunochnoye
# Processing Record6 of set6: te anau
# Processing Record7 of set6: tungor
# Processing Record8 of set6: monster
# Processing Record9 of set6: taksimo
# Processing Record10 of set6: prince rupert
# Processing Record11 of set6: hirara
# Processing Record12 of set6: kalawit
# Processing Record13 of set6: awjilah
# Processing Record14 of set6: porto santo
# Processing Record15 of set6: mtambile
# Processing Record16 of set6: mehamn
# Processing Record17 of set6: deming
# City not found. Skipping...
# Processing Record18 of set6: jining
# Processing Record19 of set6: arahal
# Processing Record20 of set6: harlingen
# Processing Record21 of set6: gladstone
# Processing Record22 of set6: mezen
# Processing Record23 of set6: narsaq
# Processing Record24 of set6: aswan
# Processing Record25 of set6: humberto de campos
# Processing Record26 of set6: sinnamary
# Processing Record27 of set6: port huron
# City not found. Skipping...
# Processing Record28 of set6: aksarka
# Processing Record29 of set6: hasaki
# Processing Record30 of set6: kamiiso
# City not found. Skipping...
# Processing Record31 of set6: cocobeach
# Processing Record32 of set6: pangnirtung
# Processing Record33 of set6: makakilo city
# Processing Record34 of set6: tromso
# Processing Record35 of set6: yenagoa
# Processing Record36 of set6: praia
# Processing Record37 of set6: namatanai
# Processing Record38 of set6: norman wells
# Processing Record39 of set6: stawell
# Processing Record40 of set6: qasigiannguit
# Processing Record41 of set6: camapua
# Processing Record42 of set6: haines junction
# Processing Record43 of set6: guaiba
# Processing Record44 of set6: amberley
# Processing Record45 of set6: brae
# Processing Record46 of set6: tamiami
# Processing Record47 of set6: corinto
# Processing Record48 of set6: havoysund
# Processing Record49 of set6: cherskiy
# Processing Record50 of set6: ramshir
# Processing Record0 of set7: pingzhuang
# Processing Record1 of set7: ahuimanu
# City not found. Skipping...
# Processing Record2 of set7: luanda
# Processing Record3 of set7: klaksvik
# Processing Record4 of set7: barra patuca
# Processing Record5 of set7: clyde river
# Processing Record6 of set7: singkang
# Processing Record7 of set7: coquimbo
# Processing Record8 of set7: bin qirdan
# Processing Record9 of set7: teahupoo
# Processing Record10 of set7: san vicente
# Processing Record11 of set7: vancouver
# Processing Record12 of set7: pontes e lacerda
# City not found. Skipping...
# Processing Record13 of set7: alyangula
# Processing Record14 of set7: codrington
# Processing Record15 of set7: chebsara
# Processing Record16 of set7: moroni
# Processing Record17 of set7: agirish
# Processing Record18 of set7: naze
# Processing Record19 of set7: rio gallegos
# Processing Record20 of set7: marsabit
# Processing Record21 of set7: najran
# Processing Record22 of set7: burkburnett
# Processing Record23 of set7: bilma
# Processing Record24 of set7: oranjemund
# Processing Record25 of set7: paso de los toros
# Processing Record26 of set7: kyzyl-suu
# Processing Record27 of set7: kosonsoy
# Processing Record28 of set7: alindao
# Processing Record29 of set7: faanui
# Processing Record30 of set7: pathein
# Processing Record31 of set7: mansehra
# Processing Record32 of set7: flinders
# Processing Record33 of set7: fukue
# Processing Record34 of set7: oliveira do hospital
# Processing Record35 of set7: bingol
# Processing Record36 of set7: plouzane
# Processing Record37 of set7: balakhonovskoye
# Processing Record38 of set7: zarinsk
# Processing Record39 of set7: sorong
# City not found. Skipping...
# Processing Record40 of set7: ovsyanka
# Processing Record41 of set7: changji
# Processing Record42 of set7: sterling
# Processing Record43 of set7: yaan
# Processing Record44 of set7: mayo
# Processing Record45 of set7: chapais
# Processing Record46 of set7: port-cartier
# Processing Record47 of set7: karratha
# Processing Record48 of set7: matagami
# Processing Record49 of set7: scottsbluff
# Processing Record50 of set7: dibrugarh
# Processing Record0 of set8: coahuayana
# Processing Record1 of set8: bonito
# Processing Record2 of set8: charters towers
# Processing Record3 of set8: risor
# Processing Record4 of set8: lalmohan
# Processing Record5 of set8: carlsbad
# Processing Record6 of set8: loubomo
# Processing Record7 of set8: port lincoln
# Processing Record8 of set8: birao
# Processing Record9 of set8: aosta
# City not found. Skipping...
# Processing Record10 of set8: ibra
# Processing Record11 of set8: upata
# Processing Record12 of set8: gazli
# Processing Record13 of set8: liwale
# City not found. Skipping...
# Processing Record14 of set8: kudahuvadhoo
# Processing Record15 of set8: vicksburg
# Processing Record16 of set8: camopi
# Processing Record17 of set8: matias olimpio
# Processing Record18 of set8: along
# Processing Record19 of set8: nieuw amsterdam
# Processing Record20 of set8: carmen
# Processing Record21 of set8: handia
# Processing Record22 of set8: nueva helvecia
# City not found. Skipping...
# Processing Record23 of set8: kulhudhuffushi
# Processing Record24 of set8: chatra
# Processing Record25 of set8: santa cruz
# Processing Record26 of set8: byron bay
# Processing Record27 of set8: piacabucu
# Processing Record28 of set8: ribas do rio pardo
# Processing Record29 of set8: kalemie
# City not found. Skipping...
# Processing Record30 of set8: pontianak
# Processing Record31 of set8: lumby
# Processing Record32 of set8: asyut
# Processing Record33 of set8: waspan
# Processing Record34 of set8: conceicao da barra
# Processing Record35 of set8: lavrentiya
# City not found. Skipping...
# Processing Record36 of set8: sainte-suzanne
# Processing Record37 of set8: zhigansk
# Processing Record38 of set8: colombo
# Processing Record39 of set8: neiafu
# Processing Record40 of set8: waiouru
# Processing Record41 of set8: fortuna
# Processing Record42 of set8: coihaique
# Processing Record43 of set8: afyonkarahisar
# Processing Record44 of set8: kaspiysk
# Processing Record45 of set8: vorontsovka
# City not found. Skipping...
# Processing Record46 of set8: bambous virieux
# Processing Record47 of set8: paralimni
# Processing Record48 of set8: half moon bay
# Processing Record49 of set8: cuamba
# Processing Record50 of set8: talara
# Processing Record0 of set9: channel-port aux basques
# Processing Record1 of set9: duyun
# Processing Record2 of set9: calvinia
# Processing Record3 of set9: staryy nadym
# City not found. Skipping...
# Processing Record4 of set9: ikungi
# Processing Record5 of set9: killybegs
# Processing Record6 of set9: marsaxlokk
# Processing Record7 of set9: ipanema
# Processing Record8 of set9: tiksi
# Processing Record9 of set9: adrar
# Processing Record10 of set9: williams lake
# Processing Record11 of set9: tarnogskiy gorodok
# Processing Record12 of set9: lokosovo
# Processing Record13 of set9: kang
# Processing Record14 of set9: mahajanga
# Processing Record15 of set9: boende
# Processing Record16 of set9: havre-saint-pierre
# Processing Record17 of set9: pangody
# Processing Record18 of set9: kirakira
# Processing Record19 of set9: mugur-aksy
# Processing Record20 of set9: sangar
# Processing Record21 of set9: umm lajj
# Processing Record22 of set9: narok
# City not found. Skipping...
# Processing Record23 of set9: kysyl-syr
# Processing Record24 of set9: moosomin
# Processing Record25 of set9: bar harbor
# Processing Record26 of set9: krasnoselkup
# Processing Record27 of set9: anloga
# City not found. Skipping...
# Processing Record28 of set9: kachug
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record29 of set9: zhangye
# Processing Record30 of set9: vitim
# Processing Record31 of set9: goya
# Processing Record32 of set9: kolpashevo
# Processing Record33 of set9: kjollefjord
# Processing Record34 of set9: vohibinany
# Processing Record35 of set9: matara
# Processing Record36 of set9: iguatemi
# Processing Record37 of set9: matamoros
# Processing Record38 of set9: lodja
# Processing Record39 of set9: kpandae
# Processing Record40 of set9: rassvet
# Processing Record41 of set9: valparaiso
# Processing Record42 of set9: bloemfontein
# Processing Record43 of set9: rosario
# Processing Record44 of set9: avera
# Processing Record45 of set9: lermontovka
# Processing Record46 of set9: balabac
# City not found. Skipping...
# Processing Record47 of set9: enid
# City not found. Skipping...
# Processing Record48 of set9: fasa
# Processing Record49 of set9: oistins
# Processing Record50 of set9: sur
# Processing Record0 of set10: nelson bay
# Processing Record1 of set10: pinotepa nacional
# Processing Record2 of set10: cravo norte
# Processing Record3 of set10: taltal
# Processing Record4 of set10: moose factory
# Processing Record5 of set10: ponta delgada
# Processing Record6 of set10: harper
# Processing Record7 of set10: novoilinsk
# Processing Record8 of set10: anadyr
# Processing Record9 of set10: todos santos
# Processing Record10 of set10: the valley
# Processing Record11 of set10: rumoi
# Processing Record12 of set10: ulaanbaatar
# Processing Record13 of set10: kloulklubed
# Processing Record14 of set10: tsaratanana
# Processing Record15 of set10: port blair
# Processing Record16 of set10: elizabeth city
# Processing Record17 of set10: aklavik
# Processing Record18 of set10: vestmannaeyjar
# Processing Record19 of set10: ucluelet
# Processing Record20 of set10: yar-sale
# Processing Record21 of set10: bairiki
# Processing Record22 of set10: boa vista
# Processing Record23 of set10: monrovia
# Processing Record24 of set10: faya
# Processing Record25 of set10: poum
# Processing Record26 of set10: bowen
# Processing Record27 of set10: korla
# Processing Record28 of set10: wad rawah
# Processing Record29 of set10: el retorno
# Processing Record30 of set10: thinadhoo
# Processing Record31 of set10: abatskoye
# Processing Record32 of set10: bilasipara
# Processing Record33 of set10: victor harbor
# Processing Record34 of set10: bushehr
# Processing Record35 of set10: pervomayskoye
# Processing Record36 of set10: abha
# Processing Record37 of set10: lingao
# Processing Record38 of set10: lewiston
# Processing Record39 of set10: chabahar
# Processing Record40 of set10: kosh-agach
# Processing Record41 of set10: tacotalpa
# Processing Record42 of set10: llanes
# Processing Record43 of set10: buraydah
# Processing Record44 of set10: marrakesh
# Processing Record45 of set10: tahe
# Processing Record46 of set10: oriximina
# Processing Record47 of set10: olenino
# Processing Record48 of set10: la rioja
# Processing Record49 of set10: terra nova
# Processing Record50 of set10: pimentel
# Processing Record0 of set11: nikolayevsk-na-amure
# Processing Record1 of set11: kaolinovo
# Processing Record2 of set11: shubarkuduk
# Processing Record3 of set11: yulara
# Processing Record4 of set11: dongying
# Processing Record5 of set11: ourossogui
# Processing Record6 of set11: nyurba
# Processing Record7 of set11: takoradi
# Processing Record8 of set11: comodoro rivadavia
# Processing Record9 of set11: kolodeznyy
# Processing Record10 of set11: los llanos de aridane
# Processing Record11 of set11: george
# Processing Record12 of set11: bilibino
# Processing Record13 of set11: pohrebyshche
# Processing Record14 of set11: van
# Processing Record15 of set11: jalu
# Processing Record16 of set11: yumen
# Processing Record17 of set11: russell
# Processing Record18 of set11: kavaratti
# Processing Record19 of set11: great yarmouth
# Processing Record20 of set11: shingu
# Processing Record21 of set11: guerrero negro
# Processing Record22 of set11: tucuman
# Processing Record23 of set11: shumskiy
# Processing Record24 of set11: de aar
# Processing Record25 of set11: denpasar
# Processing Record26 of set11: svetlogorsk
# Processing Record27 of set11: dangriga
# Processing Record28 of set11: kelowna
# Processing Record29 of set11: dzilam gonzalez
# Processing Record30 of set11: nagapattinam
# Processing Record31 of set11: sambava
# Processing Record32 of set11: yeppoon
# Processing Record33 of set11: vostok
# Processing Record34 of set11: moerai
# Processing Record35 of set11: shebalino
# Processing Record36 of set11: pulandian
# Processing Record37 of set11: auki
# Processing Record38 of set11: ankazobe
# Processing Record39 of set11: adre
# City not found. Skipping...
# Processing Record40 of set11: port hedland
# Processing Record41 of set11: tagusao
# Processing Record42 of set11: paamiut
# Processing Record43 of set11: berlevag
# Processing Record44 of set11: aykhal
# Processing Record45 of set11: iqaluit
# Processing Record46 of set11: mantua
# Processing Record47 of set11: catamarca
# Processing Record48 of set11: sakaiminato
# Processing Record49 of set11: yarkovo
# Processing Record50 of set11: zhezkazgan
# Processing Record0 of set12: falam
# Processing Record1 of set12: imbituba
# Processing Record2 of set12: el molino
# Processing Record3 of set12: carmaux
# Processing Record4 of set12: belyy yar
# Processing Record5 of set12: chipinge
# Processing Record6 of set12: zalantun
# Processing Record7 of set12: palmares do sul
# Processing Record8 of set12: darhan
# Processing Record9 of set12: dongobesh
# Processing Record10 of set12: callaway
# Processing Record11 of set12: port hardy
# Processing Record12 of set12: mashhad
# Processing Record13 of set12: ziro
# Processing Record14 of set12: alcantara
# Processing Record15 of set12: rijeka
# Processing Record16 of set12: dolores
# Processing Record17 of set12: mayskiy
# Processing Record18 of set12: kruisfontein
# Processing Record19 of set12: mareeba
# Processing Record20 of set12: sarahan
# Processing Record21 of set12: tateyama
# Processing Record22 of set12: sheffield
# Processing Record23 of set12: morena
# Processing Record24 of set12: scalea
# Processing Record25 of set12: hope
# -----------------------------
# Data Retrival Complete
# -----------------------------

# %% [markdown]
# # Convert Raw Data to DataFrame
#
# #### Export the city data into a .csv.
# #### Display the DataFrame

# %%
#Creating a dataframe with information received
Weather_pd = pd.DataFrame({
                        "City" : city_name_list, 
                        "Cloudiness" : cloudiness_list,
                        "Country" : country_list,
                        "Date" : data_list,
                        "Humidity" : humidity_list,
                        "Lat" : lat_list,
                        "Lon" : lon_list,
                        "Max Temp" : temp_max_list,
                        "Wind Speed" : wind_speed_list 
    
})

# %%
#Counting the data
Weather_pd.count()
# Out:
# City          586
# Cloudiness    586
# Country       586
# Date          586
# Humidity      586
# Lat           586
# Lon           586
# Max Temp      586
# Wind Speed    586
# dtype: int64

# %%
#Displaying the DataFrame
Weather_pd.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lon  \
# 0          Avarua          50      CK  1603933950        81 -21.21 -159.78
# 1      Butaritari         100      KI  1603933950        73   3.07  172.79
# 2  Cabo San Lucas          64      MX  1603933865        65  22.89 -109.91
# 3         Mataura          62      NZ  1603933950        72 -46.19  168.86
# 4           Airai          73      TL  1603933950        55  -8.93  125.41
#
#    Max Temp  Wind Speed
# 0     72.99       19.26
# 1     81.46        5.03
# 2     77.00        3.87
# 3     62.01        5.01
# 4     74.66        3.22

# %%
#Export city data into a .CSV file
Weather_pd.to_csv("Output_data_file", index = False)

# %% [markdown]
# # Plotting the Data
#
# #### Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# #### Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Creating the Latitude vs. Temperature Scatter Plot

#Setting the plot title, xlabel, ylabel and grid
plt.title("City Latitude vs.Max Temperature(10/27/2020)", fontsize = 20)
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Max Temperature (F)", fontsize = 12)

plt.scatter(Weather_pd["Lat"],Weather_pd["Max Temp"], facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

#Saving the plot fig as .png
plt.savefig("../Images/City Latitude vs Max Temperature.png")

# %% [markdown]
# ###### As the Latitude is increasing the temperature drops

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Creating the Latitude vs. Humidity Scatter Plot

#Setting the plot title, xlabel, ylabel and grid
plt.title("City Latitude vs. Humidity(10/27/2020)", fontsize = 20)
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Humidity (%)", fontsize = 12)

plt.scatter(Weather_pd["Lat"],Weather_pd["Humidity"], facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()


#Saving the plot fig as .png
plt.savefig("../Images/City Latitude vs Humidity.png")

# %% [markdown]
# ###### As Latitude increases Humidity also increases

# %% [markdown]
# ##  Latitude vs. Cloudiness Plot

# %%
#Creating the Latitude vs. Cloudiness Scatter Plot

#Setting the plot title, xlabel, ylabel and grid
plt.title("City Latitude vs. Cloudiness(10/27/2020)", fontsize = 20)
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Cloudiness (%)", fontsize = 12)

plt.scatter(Weather_pd["Lat"],Weather_pd["Cloudiness"], facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

#Saving the plot fig as .png
plt.savefig("../Images/City Latitude vs Cloudiness.png")

# %% [markdown]
# ###### City cloudiness is spread all over the latitude

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Creating the Latitude vs. Wind Speed Scatter Plot

#Setting the plot title, xlabel, ylabel and grid
plt.title("City Latitude vs. Wind Speed(10/27/2020)", fontsize = 20)
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Wind Speed (mph)", fontsize = 12)

plt.scatter(Weather_pd["Lat"],Weather_pd["Wind Speed"], facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

#Saving the plot fig as .png
plt.savefig("../Images/City Latitude vs Wind Speed.png")

# %% [markdown]
# ###### As the laitude increases, Wind speed is spreading at same mph

# %% [markdown]
# #  Linear Regression

# %%
#Creating DataFrame for Northern Henisphere and Southern Hemisphere
southern_hemisphere = Weather_pd.loc[Weather_pd["Lat"]<0]
northern_hemisphere = Weather_pd.loc[Weather_pd["Lat"]>=0]

# %% [markdown]
# ##  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Creating linear regression and scatter plots
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Max Temp vs Latitude Linear Regression(Northern Hemisphere)", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (10,20), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Max Temp", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

#Saving the plot fig as .png
plt.savefig("../Images/Temperatues at Latitude Positions(Northern Hemisphere.png")

# %% [markdown]
# ###### The plot shows negative correlation between Max Temp and Latitude in Northern Hemisphere

# %% [markdown]
# ##  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Max Temp vs Latitude Linear Regression(Southern Hemisphere)", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (-20,5), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Max Temp", fontsize = 12)
plt.xlim = (0, -60)
plt.ylim = (40, 100)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

#Saving the plot fig as .png
plt.savefig("../Images/Temperatues at Latitude Positions(Southern Hemisphere.png")

# %% [markdown]
# ###### The plot shows positive correlation between Max Temp and Latitude in Southern Hemisphere

# %% [markdown]
# ## Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (50,20), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Humidity (%)", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

#Saving the plot fig as .png
plt.savefig("../Images/Northern Hemisphere - Humidity (%) vs. Latitude.png")

# %% [markdown]
# ##### The plot shows moderate positive correlation between Humidity(%) and Latitude in Northern Hemisphere

# %% [markdown]
# ##  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (-20,20), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Humidity (%)", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

#Saving the plot fig as .png
plt.savefig("../Images/Southern Hemisphere - Humidity (%) vs. Latitude.png")

# %% [markdown]
# ##### The plot shows moderate positive correlation between Humidity(%) and Latitude in Southern Hemisphere

# %% [markdown]
# ## Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (10,20), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Cloudiness (%)", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

#Saving the plot fig as .png
plt.savefig("../Images/Northern Hemisphere - Cloudiness (%) vs. Latitude.png")

# %% [markdown]
# ##### The plot shows moderate positive correlation between Cloudiness(%) and Latitude in Northern Hemisphere

# %% [markdown]
# ## Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (-50,80), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Cloudiness (%)", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

#Saving the plot fig as .png
plt.savefig("../Images/Southern Hemisphere - Cloudiness (%) vs. Latitude.png")

# %% [markdown]
# ##### The plot shows positive correlation between Cloudiness(%) and Latitude in Southern Hemisphere

# %% [markdown]
# ## Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Northern Hemisphere - Wind Speed(mph) vs. Latitude", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (60,10), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Wind Speed", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

#Saving the plot fig as .png
plt.savefig("../Images/Northern Hemisphere - Wind Speed(mph) vs. Latitude.png")

# %% [markdown]
# ##### The plot shows moderate positive correlation between Wind Speed(mph) and Latitude in Northern Hemisphere

# %% [markdown]
# ## Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

#Setting the plot title, xlabel, ylabel and grid
plt.title("Southern Hemisphere - Wind Speed(mph) vs. Latitude", fontsize = 20)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (-50,8), fontsize = 12, color = "red")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Wind Speed(mph)", fontsize = 12)

plt.scatter(x_values,y_values, facecolors ="Blue",marker="o",edgecolor="black",alpha=.6)
plt.grid(linestyle="-", linewidth = 1, alpha = .5)
plt.show()

#Saving the plot fig as .png
plt.savefig("../Images/Southern Hemisphere - Wind Speed(mph) vs. Latitude.png")

# %% [markdown]
# ##### The plot shows negative correlation between Wind Speed(mph) and Latitude in Southern Hemisphere

# %% [markdown]
# ### Observations

# %% [markdown]
# ##### 1.Maximum temperature and Latitude work differently in Northern Hemishpere amd Southern Hemisphere. In Northern Hemishpere, max temperature and latitude are negatively correlated, which means that if the latitude increase max temperature decreases. Whereas in southern hemisphere its vice versa
#
# ##### 2.Cloudiness (%) and Latitude work similarly in both Northern Hemishpere amd Southern Hemisphere. The relation between cloudiness and latitude is moderately positively correlated in both hemispheres, which means as the latitude increases, the cloudiness also increases.
#
# ##### 3.For all the cities analyzed in the scatter plot, the cloudiness seem to be spead around all the latitudes.
